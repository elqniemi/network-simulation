# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import random
import copy
import simpy
import networkx as nx
from shapely.geometry import Point
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection

# %% [markdown]
# SECTION 1: PREPROCESSING & COST CALCULATIONS
#
# (a) Load the raw OSM network data (exported in osm2pgrouting format)
#     from a GeoPackage – here the layer is assumed to be named "edges".
#
# (b) Load grid statistics (100m square data) from another GeoPackage.
#     These grid cells include fields like "population", "offices", "businesses".
#
# (c) We spatially join the grid stats to each edge (using its centroid)
#     to compute a local congestion index. Then, based on the OSM “highway”
#     type we assign a free‑flow speed and a priority factor.

# %%
# Load the network edges (adjust file name and layer as needed).
edges_gdf = gpd.read_file("groningen-stad-edges.gpkg", layer="edges")

# Compute the edge length (in meters) if not already available.
if "length" not in edges_gdf.columns:
    edges_gdf["length"] = edges_gdf.geometry.length

# Load the grid statistics (adjust file name, layer, and field names as needed).
grid_gdf = gpd.read_file("grid_stats.gpkg", layer="grid_stats")
# Add id column to the grid_gdf
grid_gdf["id"] = grid_gdf.index
# Compute the centroid of each edge.
edges_gdf["centroid"] = edges_gdf.geometry.centroid
centroids = gpd.GeoDataFrame(edges_gdf[["id"]], geometry=edges_gdf["centroid"], crs=edges_gdf.crs)

# %%
edges_gdf.head()
edges_gdf.set_index("id", inplace=False)
# Out:
#        osm_way_id  source  target       highway  base_speed  priority  oneway  \
# id
# 2         4464031       3       4  unclassified        30.0       3.0       0
# 3         4694218       5       6  unclassified        60.0       3.0       0
# 4         4694219       6       7  unclassified        60.0       3.0       0
# 5         4748122       8       9   residential        30.0       1.8       0
# 6         4773008      10      11       service        30.0      10.0       0
# ...           ...     ...     ...           ...         ...       ...     ...
# 96606  1355953709   68293   83547       service        30.0      10.0       0
# 96607  1355953710   68314   83547       service        30.0      10.0       0
# 96608  1355953710   83547   68287       service        30.0      10.0       0
# 96609  1355954696   83548   83549       service        30.0      10.0       0
# 96610  1355954697   81871   83548       service        30.0      10.0       0
#
#          length_m        cost  \
# id
# 2      278.877217  100.395798
# 3      297.006020   53.461084
# 4       40.220797    7.239743
# 5       50.884553   10.991064
# 6        7.799109    9.358930
# ...           ...         ...
# 96606   66.899381   80.279258
# 96607    9.636410   11.563692
# 96608   56.340124   67.608149
# 96609    8.427313   10.112775
# 96610    9.319141   11.182970
#
#                                                 geometry      length  \
# id
# 2      LINESTRING (232097.781 580026.024, 232112.632 ...  278.877217
# 3      LINESTRING (229494.721 586385.619, 229526.469 ...  297.006020
# 4      LINESTRING (229781.539 586332.55, 229821.582 5...   40.220797
# 5      LINESTRING (233657.388 578848.762, 233609.467 ...   50.884553
# 6      LINESTRING (231810.57 586799.947, 231817.972 5...    7.799109
# ...                                                  ...         ...
# 96606  LINESTRING (239088.637 574374.686, 239082.427 ...   66.899381
# 96607  LINESTRING (239025.781 574376.629, 239023.434 ...    9.636410
# 96608  LINESTRING (239023.434 574367.282, 239017.583 ...   56.340124
# 96609  LINESTRING (241736.204 577710.413, 241743.935 ...    8.427313
# 96610  LINESTRING (241727.658 577706.697, 241736.204 ...    9.319141
#
#                             centroid
# id
# 2      POINT (232205.651 580113.137)
# 3      POINT (229636.539 586345.724)
# 4       POINT (229801.56 586334.442)
# 5      POINT (233633.427 578840.206)
# 6      POINT (231814.271 586801.175)
# ...                              ...
# 96606  POINT (239056.735 574368.268)
# 96607  POINT (239024.607 574371.956)
# 96608  POINT (238997.293 574357.816)
# 96609   POINT (241740.07 577712.091)
# 96610  POINT (241731.931 577708.555)
#
# [20676 rows x 12 columns]

# %%
def check_network_connectivity(G):
    if nx.is_strongly_connected(G):
        print("The network is strongly connected.")
    else:
        print("The network is not strongly connected.")
        components = list(nx.strongly_connected_components(G))
        print(f"Number of strongly connected components: {len(components)}")
        print(f"Sizes of components: {[len(c) for c in components]}")

# %%
# Spatial join: for each edge (via its centroid) join the grid stats.
# (Using the predicate "within" – newer versions of GeoPandas support "predicate".)
joined = gpd.sjoin(centroids, grid_gdf, how="left", predicate="within")

# Check if 'id' column exists in joined DataFrame
if 'id' not in joined.columns:
    print("Warning: 'id' column not found in joined DataFrame. Using index as id.")
    joined['id'] = joined.index

# Select only the columns we need
joined_subset = joined[['id', 'population', 'offices', 'shops']]

# Merge with edges_gdf
edges_gdf = edges_gdf.merge(joined_subset, on="id", how="left")

for field in ["population", "offices", "shops"]:
    edges_gdf[field] = edges_gdf[field].fillna(0)
    # Make the ceiling 10000 for the original data.
    edges_gdf[field] = edges_gdf[field].clip(0, 10000)

# Define a function to compute a congestion index based on local grid stats.
def compute_congestion_index(population, offices, businesses):
    # We use arbitrary weights – adjust as needed.
    pop_factor = population / 1000.0
    office_factor = offices / 500.0
    business_factor = businesses / 500.0
    return 0.5 * pop_factor + 0.3 * office_factor + 0.2 * business_factor

edges_gdf["congestion_index"] = edges_gdf.apply(
    lambda row: compute_congestion_index(row["population"], row["offices"], row["shops"]),
    axis=1
)
# Out:
# Warning: 'id' column not found in joined DataFrame. Using index as id.

# %%
# (Optional) You can smooth the congestion indices over adjacent edges.
def smooth_congestion_indices(edges_gdf, alpha=0.7, iterations=3):
    updated = edges_gdf.set_index("id")["congestion_index"].to_dict()
    # Build a node-to-edge mapping.
    node_to_edges = {}
    for _, row in edges_gdf.iterrows():
        src = row["source"]
        tgt = row["target"]
        node_to_edges.setdefault(src, []).append(row["id"])
        node_to_edges.setdefault(tgt, []).append(row["id"])
    for _ in range(iterations):
        new_vals = {}
        for _, row in edges_gdf.iterrows():
            eid = row["id"]
            src = row["source"]
            tgt = row["target"]
            neighbor_ids = set(node_to_edges.get(src, []) + node_to_edges.get(tgt, [])) - {eid}
            # For one-way edges, you might restrict neighbors (not done here).
            if neighbor_ids:
                neighbor_avg = np.mean([updated[nid] for nid in neighbor_ids])
                new_vals[eid] = alpha * updated[eid] + (1 - alpha) * neighbor_avg
            else:
                new_vals[eid] = updated[eid]
        updated = new_vals
    edges_gdf["smoothed_congestion_index"] = edges_gdf["id"].map(updated)
    return edges_gdf

edges_gdf = smooth_congestion_indices(edges_gdf, alpha=0.7, iterations=3)

# %% [markdown]
# SECTION 2: BUILDING THE GRAPH & INITIAL COST TABLE (per time-of-day)
#
# Although our dynamic simulation will re‑compute travel times on the fly,
# we first build a directed NetworkX graph using the “modified” edge data.
#
# We also compute a “static” weight based on free‑flow travel time.
# Additionally, we compute a capacity for each edge based on its length
# and a per‑km density that depends on the road type.

# %%
# Compute capacity for each edge (vehicles per km * length in km).
road_capacity_density = {
    "motorway":      150,
    "motorway_link": 150,
    "trunk":         120,
    "trunk_link":    120,
    "primary":       100,
    "primary_link":  100,
    "secondary":     80,
    "secondary_link": 80,
    "tertiary":      60,
    "tertiary_link": 60,
    "residential":   40,
    "living_street": 40,
    "service":       30,
    "unclassified":  50,
}
default_density = 50

def compute_capacity(row):
    density = road_capacity_density.get(row["highway"], default_density)
    return (row["length"] / 1000.0) * density

edges_gdf["capacity"] = edges_gdf.apply(compute_capacity, axis=1)

# Calculate travel time in seconds
edges_gdf["travel_time_sec"] = edges_gdf["length"] / (edges_gdf["base_speed"] / 3.6)  # Convert km/h to m/s

# Build the directed graph G.
G = nx.DiGraph()
for _, row in edges_gdf.iterrows():
    # Add the forward edge
    G.add_edge(
        row["source"],
        row["target"],
        weight=row["travel_time_sec"],       # free‑flow travel time (static cost)
        edge_id=row["id"],
        travel_time_sec=row["travel_time_sec"],
        capacity=row["capacity"],
        length=row["length"],
        average_speed=row["base_speed"],
        oneway=row["oneway"]
    )
    
    # Add the reverse edge if it's not a one-way street (oneway == 0)
    if row["oneway"] == 0:
        G.add_edge(
            row["target"],
            row["source"],
            weight=row["travel_time_sec"],       # free‑flow travel time (static cost)
            edge_id=f"{row['id']}_rev",  # Add a suffix to distinguish reverse edges
            travel_time_sec=row["travel_time_sec"],
            capacity=row["capacity"],
            length=row["length"],
            average_speed=row["base_speed"],
            oneway=0
        )

# Build a list of nodes (used later for selecting origins/destinations).
nodes_list = list(G.nodes())

# For visualization later, create a mapping from edge_id to geometry.
edge_geometries = {row["id"]: row.geometry for _, row in edges_gdf.iterrows()}

# %% [markdown]
# SECTION 3: SIMULATION PARAMETERS & TIME-OF-DAY PATTERNS
#
# We define a simulation start time (in seconds since midnight) and a total simulation
# duration. Vehicles will be spawned at rates that depend on the time-of-day,
# and realistic origin/destination patterns (e.g. morning: residential → office).

# %%
SIM_START = 6 * 3600        # e.g., simulation “clock” starts at 6:00 AM
SIM_DURATION = 6 * 3600     # simulate 6 hours (adjust as needed)

# Base parameters for vehicle generation.
BASE_BATCH_SIZE = 10         # base vehicles per batch
BASE_BATCH_INTERVAL = 60     # seconds between batches (5 minutes)

# Tagging nodes based on grid cell statistics
grid_sindex = grid_gdf.sindex

# Function to get the grid cell for a given point
def get_grid_cell(point):
    possible_matches_index = list(grid_sindex.intersection(point.bounds))
    possible_matches = grid_gdf.iloc[possible_matches_index]
    precise_matches = possible_matches[possible_matches.contains(point)]
    if len(precise_matches) > 0:
        return precise_matches.iloc[0]
    return None

# Create a dictionary of node coordinates
node_coords = {}
for _, row in edges_gdf.iterrows():
    geom = row.geometry
    node_coords[row['source']] = Point(geom.coords[0])
    node_coords[row['target']] = Point(geom.coords[-1])

# Create a GeoDataFrame of nodes
nodes_gdf = gpd.GeoDataFrame(
    {'id': list(G.nodes())},
    geometry=[node_coords[node] for node in G.nodes()],
    crs=grid_gdf.crs
)

# Tag nodes based on grid cell statistics
residential_nodes = []
office_nodes = []

for _, node in nodes_gdf.iterrows():
    cell = get_grid_cell(node.geometry)
    if cell is not None:
        if cell['population'] > cell['offices'] * 2:  # More residential
            residential_nodes.append(node['id'])
        elif cell['offices'] > cell['population'] * 0.5:  # More office-oriented
            office_nodes.append(node['id'])
        else:  # Mixed use, randomly assign
            if random.random() < 0.5:
                residential_nodes.append(node['id'])
            else:
                office_nodes.append(node['id'])
    else:  # If node is not in any cell, randomly assign
        if random.random() < 0.7:  # Keeping the 70% residential ratio
            residential_nodes.append(node['id'])
        else:
            office_nodes.append(node['id'])

print(f"Tagged {len(residential_nodes)} residential nodes and {len(office_nodes)} office nodes.")
# Out:
# Tagged 7932 residential nodes and 8883 office nodes.

# %%
def get_time_period(sim_time):
    """Return a string (morning/day/evening/night) based on effective time-of-day."""
    effective = (SIM_START + sim_time) % 86400
    hour = effective // 3600
    if 6 <= hour < 10:
        return "morning"
    elif 16 <= hour < 20:
        return "evening"
    elif 10 <= hour < 16:
        return "day"
    else:
        return "night"

def get_spawn_multiplier(sim_time):
    """Return a multiplier for vehicle batch size based on time-of-day."""
    period = get_time_period(sim_time)
    if period in ["morning", "evening"]:
        return random.randint(2, 5)
    elif period == "night":
        return 0.5
    else:
        return random.randint(1, 2)

def get_origin_destination(sim_time):
    """
    Choose realistic origin and destination nodes based on time-of-day.
      - Morning: residential → office.
      - Evening: office → residential.
      - Otherwise: random.
    """
    period = get_time_period(sim_time)
    if period == "morning":
        return random.choice(residential_nodes), random.choice(office_nodes)
    elif period == "evening":
        return random.choice(office_nodes), random.choice(residential_nodes)
    else:
        return random.choice(nodes_list), random.choice(nodes_list)

def route_length(route):
    """Return total route length in meters (given a list of edge dictionaries)."""
    return sum(edge["length"] for edge in route)

# %% [markdown]
# SECTION 4: DYNAMIC CONGESTION FEEDBACK & RE‑ROUTING FUNCTIONS
#
# A global dictionary (dynamic_occupancy) will keep track of the number
# of vehicles on each edge at any time. We also record snapshots for visualization.

# %%
dynamic_occupancy = {edge_data["edge_id"]: 0 for u, v, edge_data in G.edges(data=True)}
occupancy_snapshots = []  # list of tuples: (simulation time, copy of occupancy dict)

# Parameters for the dynamic (BPR‑like) function.
alpha_dyn = 0.25
beta_dyn = 5.0

RE_ROUTE_THRESHOLD = 0.8   # if occupancy/capacity exceeds this, vehicles re-route

def occupancy_monitor(env, snapshot_interval=10):
    """Periodically record occupancy snapshots for visualization."""
    while True:
        occupancy_snapshots.append((env.now, copy.deepcopy(dynamic_occupancy)))
        yield env.timeout(snapshot_interval)

# -----------------------------------------------------------------------------
# Routing functions:
# (a) compute_route_for_vehicle: static (initial) route using Dijkstra.
# (b) compute_dynamic_route: re‑compute route on the fly using current occupancy.
# (c) compute_dynamic_route_snapshot: for route queries at a given time.
# -----------------------------------------------------------------------------

def compute_route_for_vehicle(G, source_node, destination):
    try:
        route_nodes = nx.shortest_path(G, source=source_node, target=destination, weight="weight")
    except nx.NetworkXNoPath:
        return None
    route_edges = []
    for u, v in zip(route_nodes[:-1], route_nodes[1:]):
        data = G.get_edge_data(u, v)
        route_edges.append({
            "edge_id": data["edge_id"],
            "from_node": u,
            "to_node": v,
            "travel_time_sec": data["travel_time_sec"],
            "capacity": data["capacity"],
            "length": data["length"],
            "average_speed": data["average_speed"]
        })
    return route_edges

def compute_dynamic_route(G, current_node, destination):
    """
    Build a temporary graph with updated weights using current dynamic occupancy.
    Weight = free_flow_time * (1 + alpha_dyn * ((occ + 1) / capacity) ** beta_dyn)
    """
    G_dynamic = nx.DiGraph()
    for u, v, data in G.edges(data=True):
        occ = dynamic_occupancy.get(data["edge_id"], 0)
        cap = data["capacity"]
        free_flow = data["travel_time_sec"]
        dynamic_weight = free_flow * (1 + alpha_dyn * ((occ + 1) / cap) ** beta_dyn)
        new_data = data.copy()
        new_data["weight"] = dynamic_weight
        G_dynamic.add_edge(u, v, **new_data)
    try:
        route_nodes = nx.shortest_path(G_dynamic, source=current_node, target=destination, weight="weight")
    except nx.NetworkXNoPath:
        return None
    route_edges = []
    for u, v in zip(route_nodes[:-1], route_nodes[1:]):
        data = G.get_edge_data(u, v)
        route_edges.append({
            "edge_id": data["edge_id"],
            "from_node": u,
            "to_node": v,
            "travel_time_sec": data["travel_time_sec"],
            "capacity": data["capacity"],
            "length": data["length"],
            "average_speed": data["average_speed"]
        })
    return route_edges

def compute_dynamic_route_snapshot(G, current_node, destination, occ_snapshot):
    """
    Like compute_dynamic_route() but uses a provided occupancy snapshot.
    """
    G_dynamic = nx.DiGraph()
    for u, v, data in G.edges(data=True):
        occ = occ_snapshot.get(data["edge_id"], 0)
        cap = data["capacity"]
        free_flow = data["travel_time_sec"]
        dynamic_weight = free_flow * (1 + alpha_dyn * ((occ + 1) / cap) ** beta_dyn)
        new_data = data.copy()
        new_data["weight"] = dynamic_weight
        G_dynamic.add_edge(u, v, **new_data)
    try:
        route_nodes = nx.shortest_path(G_dynamic, source=current_node, target=destination, weight="weight")
    except nx.NetworkXNoPath:
        return None
    route_edges = []
    for u, v in zip(route_nodes[:-1], route_nodes[1:]):
        data = G.get_edge_data(u, v)
        route_edges.append({
            "edge_id": data["edge_id"],
            "from_node": u,
            "to_node": v,
            "travel_time_sec": data["travel_time_sec"],
            "capacity": data["capacity"],
            "length": data["length"],
            "average_speed": data["average_speed"]
        })
    return route_edges
    # routes = list(nx.shortest_simple_paths(G_dynamic, current_node, destination, weight="weight"))
    # best_route = None
    # best_time = float('inf')
    # k = 5
    
    # for route_nodes in routes[:k]:  # Consider top k routes
    #     route_edges = []
    #     total_time = 0
    #     for u, v in zip(route_nodes[:-1], route_nodes[1:]):
    #         data = G.get_edge_data(u, v)
    #         edge_time = data["travel_time_sec"] * (1 + alpha_dyn * ((occ_snapshot.get(data["edge_id"], 0) + 1) / data["capacity"]) ** beta_dyn)
    #         total_time += edge_time
    #         route_edges.append({
    #             "edge_id": data["edge_id"],
    #             "from_node": u,
    #             "to_node": v,
    #             "travel_time_sec": data["travel_time_sec"],
    #             "capacity": data["capacity"],
    #             "length": data["length"],
    #             "average_speed": data["average_speed"]
    #         })
    #     if total_time < best_time:
    #         best_time = total_time
    #         best_route = route_edges
    
    # return best_route

# %% [markdown]
# SECTION 5: VEHICLE PROCESS & GENERATION
#
# Each vehicle follows its route edge-by-edge. Before entering an edge,
# it checks if the occupancy fraction exceeds the threshold. If so, it re-computes
# a new route from its current node to the destination.
# In addition, we enforce that the route must be at least 2 km long.

# %%
def vehicle_process(env, vehicle_id, route_edges, destination):
    """
    Each vehicle traverses its route edge-by-edge.
    Before entering an edge, if its occupancy fraction exceeds the threshold,
    the vehicle re-computes a new route from its current node to the destination.
    To avoid infinite re-routing loops, we limit the number of consecutive re-routes.
    """
    if not route_edges:
        return
    current_node = route_edges[0]["from_node"]
    i = 0
    reroute_attempts = 0
    MAX_REROUTES = 3  # maximum number of re-route attempts before proceeding
    while i < len(route_edges):
        edge = route_edges[i]
        occ = dynamic_occupancy.get(edge["edge_id"], 0)
        cap = edge["capacity"]
        # If the occupancy is above the threshold and we haven't exceeded max re-routes...
        if (occ / cap) > RE_ROUTE_THRESHOLD:
            if reroute_attempts < MAX_REROUTES:
                new_route = compute_dynamic_route(G, current_node, destination)
                if new_route is not None:
                    print(f"[Time {env.now:5.1f} sec] Vehicle {vehicle_id} re-routing from node {current_node} due to congestion on edge {edge['edge_id']}.")
                    route_edges = new_route  # adopt the new route
                    i = 0  # reset to the start of the new route
                    reroute_attempts += 1
                    continue  # re-check the first edge of the new route
            else:
                # Maximum re-route attempts reached; proceed on current route despite congestion.
                print(f"[Time {env.now:5.1f} sec] Vehicle {vehicle_id} reached maximum re-route attempts at node {current_node}. Proceeding on current route.")
        # Reset the counter once an edge is successfully entered.
        reroute_attempts = 0
        # Vehicle enters the edge.
        dynamic_occupancy[edge["edge_id"]] += 1
        occ_new = dynamic_occupancy[edge["edge_id"]]
        free_flow_time = edge["travel_time_sec"]
        travel_time = free_flow_time * (1 + alpha_dyn * ((occ_new) / cap) ** beta_dyn)
        yield env.timeout(travel_time)
        dynamic_occupancy[edge["edge_id"]] -= 1
        current_node = edge["to_node"]
        i += 1
    print(f"[Time {env.now:5.1f} sec] Vehicle {vehicle_id} reached destination {destination}.")

def vehicle_generator(env):
    """
    Generate vehicles in batches. Batch size is modulated by time-of-day.
    Each vehicle’s origin and destination are chosen based on realistic patterns.
    Only routes with a total length of at least 2 km are accepted.
    """
    vehicle_id = 0
    while env.now < SIM_DURATION:
        multiplier = get_spawn_multiplier(env.now)
        batch_size = int(BASE_BATCH_SIZE * multiplier)
        for _ in range(batch_size):
            source, destination = get_origin_destination(env.now)
            if source == destination:
                continue
            attempts = 0
            route = None
            while attempts < 10:
                route = compute_route_for_vehicle(G, source, destination)
                if route and (route_length(route) >= 2000):
                    break
                source, destination = get_origin_destination(env.now)
                attempts += 1
            if route is None or route_length(route) < 2000:
                continue
            env.process(vehicle_process(env, vehicle_id, route, destination))
            vehicle_id += 1
        print(f"[Sim Time {env.now:5.1f} sec] Launched batch of {batch_size} vehicles.")
        yield env.timeout(BASE_BATCH_INTERVAL)

def run_simulation():
    """
    Set up and run the SimPy environment:
      - Start occupancy monitoring.
      - Start vehicle generation.
      - Run until SIM_DURATION.
    """
    env = simpy.Environment()
    env.process(occupancy_monitor(env, snapshot_interval=10))
    env.process(vehicle_generator(env))
    env.run(until=SIM_DURATION)
    print("Simulation complete.")

# %% [markdown]
# SECTION 6: ROUTE QUERY FUNCTIONALITY
#
# These functions allow you to “freeze” the dynamic state at a given time
# (using recorded occupancy snapshots) and compute a route for a given OD pair.

# %%
def query_route_at_time(query_time, source, destination):
    if not occupancy_snapshots:
        print("No occupancy snapshots available.")
        return None
    closest_snapshot = min(occupancy_snapshots, key=lambda snap: abs(snap[0] - query_time))
    snap_time, occ_snapshot = closest_snapshot
    print(f"Query time: {query_time} sec; using occupancy snapshot at {snap_time} sec.")
    route = compute_dynamic_route_snapshot(G, source, destination, occ_snapshot)
    
    if route:
        # Calculate the estimated travel time
        total_time = sum(
            edge["travel_time_sec"] * (1 + alpha_dyn * ((occ_snapshot.get(edge["edge_id"], 0) + 1) / edge["capacity"]) ** beta_dyn)
            for edge in route
        )
        return route, total_time
    return None, None

def query_routes_at_intervals(source, destination, interval=3600, total_duration=SIM_DURATION):
    queries = []
    t = 0
    while t <= total_duration:
        route, travel_time = query_route_at_time(t, source, destination)
        queries.append((t, route, travel_time))
        t += interval
    return queries

# %%
# Run the dynamic simulation.
run_simulation()
# Out:
# [Sim Time   0.0 sec] Launched batch of 20 vehicles.
# [Sim Time  60.0 sec] Launched batch of 20 vehicles.
# [Time  72.5 sec] Vehicle 15 re-routing from node 32154 due to congestion on edge 31995_rev.
# [Sim Time 120.0 sec] Launched batch of 40 vehicles.
# [Time 144.6 sec] Vehicle 55 re-routing from node 32308 due to congestion on edge 46474.
# [Time 161.2 sec] Vehicle 40 re-routing from node 68319 due to congestion on edge 84583_rev.
# [Sim Time 180.0 sec] Launched batch of 50 vehicles.
# [Time 182.4 sec] Vehicle 67 re-routing from node 74768 due to congestion on edge 80337.
# [Time 208.0 sec] Vehicle 29 reached destination 74304.
# [Time 214.7 sec] Vehicle 101 re-routing from node 48668 due to congestion on edge 80337_rev.
# [Time 216.4 sec] Vehicle 36 re-routing from node 48663 due to congestion on edge 49073_rev.
# [Time 232.9 sec] Vehicle 1 reached destination 32402.
# [Sim Time 240.0 sec] Launched batch of 50 vehicles.
# [Time 261.0 sec] Vehicle 171 re-routing from node 7198 due to congestion on edge 6878.
# [Time 261.0 sec] Vehicle 171 re-routing from node 7198 due to congestion on edge 6878.
# [Time 261.0 sec] Vehicle 171 re-routing from node 7198 due to congestion on edge 6878.
# [Time 261.0 sec] Vehicle 171 reached maximum re-route attempts at node 7198. Proceeding on current route.
# [Time 283.6 sec] Vehicle 32 reached destination 81451.
# [Sim Time 300.0 sec] Launched batch of 50 vehicles.
# [Time 305.7 sec] Vehicle 17 reached destination 43517.
# [Time 307.6 sec] Vehicle 200 re-routing from node 29449 due to congestion on edge 29284_rev.
# [Time 313.9 sec] Vehicle 132 re-routing from node 51008 due to congestion on edge 51864_rev.
# [Time 313.9 sec] Vehicle 132 re-routing from node 51008 due to congestion on edge 51864_rev.
# [Time 313.9 sec] Vehicle 132 re-routing from node 51008 due to congestion on edge 51864_rev.
# [Time 313.9 sec] Vehicle 132 reached maximum re-route attempts at node 51008. Proceeding on current route.
# [Time 316.0 sec] Vehicle 213 re-routing from node 69189 due to congestion on edge 71629.
# [Time 319.7 sec] Vehicle 214 re-routing from node 81634 due to congestion on edge 92914_rev.
# [Time 325.7 sec] Vehicle 68 re-routing from node 64581 due to congestion on edge 81401.
# [Time 326.9 sec] Vehicle 181 re-routing from node 29886 due to congestion on edge 29668_rev.
# [Time 343.0 sec] Vehicle 4 reached destination 30525.
# [Time 343.3 sec] Vehicle 112 re-routing from node 44950 due to congestion on edge 86296.
# [Time 344.7 sec] Vehicle 160 re-routing from node 51008 due to congestion on edge 51864_rev.
# [Time 344.7 sec] Vehicle 160 re-routing from node 51008 due to congestion on edge 51864_rev.
# [Time 344.7 sec] Vehicle 160 re-routing from node 51008 due to congestion on edge 51864_rev.
# [Time 344.7 sec] Vehicle 160 reached maximum re-route attempts at node 51008. Proceeding on current route.
# [Time 355.7 sec] Vehicle 44 re-routing from node 66110 due to congestion on edge 82716.
# [Time 355.7 sec] Vehicle 44 re-routing from node 66110 due to congestion on edge 82716.
# [Time 355.7 sec] Vehicle 44 re-routing from node 66110 due to congestion on edge 82716.
# [Time 355.7 sec] Vehicle 44 reached maximum re-route attempts at node 66110. Proceeding on current route.
# [Time 358.9 sec] Vehicle 81 re-routing from node 75671 due to congestion on edge 82718_rev.
# [Sim Time 360.0 sec] Launched batch of 40 vehicles.
# [Time 363.8 sec] Vehicle 152 re-routing from node 81634 due to congestion on edge 92914_rev.
# [Time 365.4 sec] Vehicle 114 reached destination 48617.
# [Time 365.7 sec] Vehicle 182 re-routing from node 32254 due to congestion on edge 82642_rev.
# [Time 370.5 sec] Vehicle 86 re-routing from node 68319 due to congestion on edge 84583_rev.
# [Time 375.0 sec] Vehicle 193 re-routing from node 66110 due to congestion on edge 82716.
# [Time 375.0 sec] Vehicle 193 re-routing from node 66110 due to congestion on edge 82716.
# [Time 375.0 sec] Vehicle 193 re-routing from node 66110 due to congestion on edge 82716.
# [Time 375.0 sec] Vehicle 193 reached maximum re-route attempts at node 66110. Proceeding on current route.
# [Time 375.2 sec] Vehicle 217 re-routing from node 66110 due to congestion on edge 82716.
# [Time 375.2 sec] Vehicle 217 re-routing from node 66110 due to congestion on edge 82716.
# [Time 375.2 sec] Vehicle 217 re-routing from node 66110 due to congestion on edge 82716.
# [Time 375.2 sec] Vehicle 217 reached maximum re-route attempts at node 66110. Proceeding on current route.
# [Time 375.7 sec] Vehicle 80 reached destination 29099.
# [Time 377.4 sec] Vehicle 7 reached destination 40398.
# [Time 379.7 sec] Vehicle 243 re-routing from node 29344 due to congestion on edge 29333.
# [Time 379.7 sec] Vehicle 243 re-routing from node 29344 due to congestion on edge 29333.
# [Time 379.7 sec] Vehicle 243 re-routing from node 29344 due to congestion on edge 29333.
# [Time 379.7 sec] Vehicle 243 reached maximum re-route attempts at node 29344. Proceeding on current route.
# [Time 381.2 sec] Vehicle 85 reached destination 33583.
# [Time 388.8 sec] Vehicle 244 re-routing from node 64602 due to congestion on edge 65360.
# [Time 394.3 sec] Vehicle 13 reached destination 49007.
# [Time 394.6 sec] Vehicle 256 re-routing from node 66636 due to congestion on edge 71631.
# [Time 398.5 sec] Vehicle 31 re-routing from node 43262 due to congestion on edge 42922.
# [Time 415.2 sec] Vehicle 93 reached destination 64910.
# [Sim Time 420.0 sec] Launched batch of 30 vehicles.
# [Time 420.3 sec] Vehicle 139 re-routing from node 74768 due to congestion on edge 80337.
# [Time 426.1 sec] Vehicle 263 re-routing from node 33469 due to congestion on edge 34363_rev.
# [Time 427.8 sec] Vehicle 23 reached destination 7534.
# [Time 429.1 sec] Vehicle 115 re-routing from node 74768 due to congestion on edge 80337.
# [Time 429.9 sec] Vehicle 39 re-routing from node 75611 due to congestion on edge 82521.
# [Time 429.9 sec] Vehicle 39 re-routing from node 75611 due to congestion on edge 82521.
# [Time 429.9 sec] Vehicle 39 re-routing from node 75611 due to congestion on edge 82521.
# [Time 429.9 sec] Vehicle 39 reached maximum re-route attempts at node 75611. Proceeding on current route.
# [Time 431.2 sec] Vehicle 12 reached destination 76096.
# [Time 436.8 sec] Vehicle 265 re-routing from node 32884 due to congestion on edge 32751.
# [Time 443.6 sec] Vehicle 163 re-routing from node 68319 due to congestion on edge 84583_rev.
# [Time 443.9 sec] Vehicle 262 re-routing from node 31404 due to congestion on edge 31494.
# [Time 446.9 sec] Vehicle 43 re-routing from node 75031 due to congestion on edge 80912.
# [Time 446.9 sec] Vehicle 43 re-routing from node 75031 due to congestion on edge 80912.
# [Time 446.9 sec] Vehicle 43 re-routing from node 75031 due to congestion on edge 80912.
# [Time 446.9 sec] Vehicle 43 reached maximum re-route attempts at node 75031. Proceeding on current route.
# [Time 448.6 sec] Vehicle 124 re-routing from node 66110 due to congestion on edge 82716.
# [Time 448.6 sec] Vehicle 124 re-routing from node 66110 due to congestion on edge 82716.
# [Time 448.6 sec] Vehicle 124 re-routing from node 66110 due to congestion on edge 82716.
# [Time 448.6 sec] Vehicle 124 reached maximum re-route attempts at node 66110. Proceeding on current route.
# [Time 448.7 sec] Vehicle 142 re-routing from node 75671 due to congestion on edge 82718_rev.
# [Time 449.2 sec] Vehicle 188 re-routing from node 77288 due to congestion on edge 85544.
# [Time 449.6 sec] Vehicle 122 reached destination 30422.
# [Time 453.1 sec] Vehicle 248 re-routing from node 68319 due to congestion on edge 84583_rev.
# [Time 457.8 sec] Vehicle 8 reached destination 75606.
# [Time 458.9 sec] Vehicle 51 reached destination 44824.
# [Time 461.4 sec] Vehicle 11 reached destination 39277.
# [Time 462.0 sec] Vehicle 138 re-routing from node 33826 due to congestion on edge 33684.
# [Time 463.2 sec] Vehicle 0 reached destination 45519.
# [Time 466.5 sec] Vehicle 197 re-routing from node 68319 due to congestion on edge 84583_rev.
# [Time 472.8 sec] Vehicle 296 re-routing from node 30649 due to congestion on edge 51063_rev.
# [Time 472.8 sec] Vehicle 296 re-routing from node 30649 due to congestion on edge 51063_rev.
# [Time 472.8 sec] Vehicle 296 re-routing from node 30649 due to congestion on edge 51063_rev.
# [Time 472.8 sec] Vehicle 296 reached maximum re-route attempts at node 30649. Proceeding on current route.
# [Time 473.1 sec] Vehicle 64 re-routing from node 29978 due to congestion on edge 70040.
# [Time 473.1 sec] Vehicle 64 re-routing from node 29978 due to congestion on edge 70040.
# [Time 473.1 sec] Vehicle 64 re-routing from node 29978 due to congestion on edge 70040.
# [Time 473.1 sec] Vehicle 64 reached maximum re-route attempts at node 29978. Proceeding on current route.
# [Time 477.0 sec] Vehicle 98 reached destination 30564.
# [Time 477.0 sec] Vehicle 151 re-routing from node 74768 due to congestion on edge 80337.
# [Time 478.0 sec] Vehicle 81 re-routing from node 44276 due to congestion on edge 67997.
# [Sim Time 480.0 sec] Launched batch of 40 vehicles.
# [Time 480.0 sec] Vehicle 307 re-routing from node 44173 due to congestion on edge 44779.
# [Time 481.5 sec] Vehicle 152 reached destination 32864.
# [Time 485.7 sec] Vehicle 312 re-routing from node 74684 due to congestion on edge 80123.
# [Time 485.8 sec] Vehicle 111 reached destination 28827.
# [Time 486.7 sec] Vehicle 324 re-routing from node 32884 due to congestion on edge 32751.
# [Time 487.2 sec] Vehicle 77 reached destination 33918.
# [Time 487.5 sec] Vehicle 330 re-routing from node 32468 due to congestion on edge 32287_rev.
# [Time 487.5 sec] Vehicle 330 re-routing from node 32468 due to congestion on edge 32287_rev.
# [Time 487.5 sec] Vehicle 330 re-routing from node 32468 due to congestion on edge 32287_rev.
# [Time 487.5 sec] Vehicle 330 reached maximum re-route attempts at node 32468. Proceeding on current route.
# [Time 492.3 sec] Vehicle 314 re-routing from node 66110 due to congestion on edge 82716.
# [Time 492.3 sec] Vehicle 314 re-routing from node 66110 due to congestion on edge 82716.
# [Time 492.3 sec] Vehicle 314 re-routing from node 66110 due to congestion on edge 82716.
# [Time 492.3 sec] Vehicle 314 reached maximum re-route attempts at node 66110. Proceeding on current route.
# [Time 493.1 sec] Vehicle 65 reached destination 29496.
# [Time 496.7 sec] Vehicle 68 reached destination 43644.
# [Time 501.7 sec] Vehicle 183 re-routing from node 74768 due to congestion on edge 80337.
# [Time 504.3 sec] Vehicle 3 reached destination 31943.
# [Time 505.7 sec] Vehicle 258 re-routing from node 68384 due to congestion on edge 71379.
# [Time 505.7 sec] Vehicle 258 re-routing from node 68384 due to congestion on edge 71379.
# [Time 505.7 sec] Vehicle 258 re-routing from node 68384 due to congestion on edge 71379.
# [Time 505.7 sec] Vehicle 258 reached maximum re-route attempts at node 68384. Proceeding on current route.
# [Time 508.8 sec] Vehicle 215 reached destination 46465.
# [Time 510.6 sec] Vehicle 283 re-routing from node 75031 due to congestion on edge 80912.
# [Time 510.6 sec] Vehicle 283 re-routing from node 75031 due to congestion on edge 80912.
# [Time 510.6 sec] Vehicle 283 re-routing from node 75031 due to congestion on edge 80912.
# [Time 510.6 sec] Vehicle 283 reached maximum re-route attempts at node 75031. Proceeding on current route.
# [Time 513.6 sec] Vehicle 106 re-routing from node 72052 due to congestion on edge 75783.
# [Time 513.6 sec] Vehicle 106 re-routing from node 72052 due to congestion on edge 75783.
# [Time 513.6 sec] Vehicle 106 re-routing from node 72052 due to congestion on edge 75783.
# [Time 513.6 sec] Vehicle 106 reached maximum re-route attempts at node 72052. Proceeding on current route.
# [Time 514.6 sec] Vehicle 299 re-routing from node 75668 due to congestion on edge 82717.
# [Time 514.6 sec] Vehicle 299 re-routing from node 75668 due to congestion on edge 82717.
# [Time 514.6 sec] Vehicle 299 re-routing from node 75668 due to congestion on edge 82717.
# [Time 514.6 sec] Vehicle 299 reached maximum re-route attempts at node 75668. Proceeding on current route.
# [Time 517.5 sec] Vehicle 40 reached destination 66489.
# [Time 521.3 sec] Vehicle 30 re-routing from node 75671 due to congestion on edge 82718_rev.
# [Time 529.0 sec] Vehicle 188 re-routing from node 74337 due to congestion on edge 79185.
# [Time 532.3 sec] Vehicle 335 re-routing from node 32884 due to congestion on edge 32751.
# [Time 535.0 sec] Vehicle 312 re-routing from node 74681 due to congestion on edge 91051.
# [Time 535.0 sec] Vehicle 312 re-routing from node 74681 due to congestion on edge 91051.
# [Time 535.0 sec] Vehicle 312 re-routing from node 74681 due to congestion on edge 91051.
# [Time 535.0 sec] Vehicle 312 reached maximum re-route attempts at node 74681. Proceeding on current route.
# [Time 535.8 sec] Vehicle 64 reached destination 44910.
# [Sim Time 540.0 sec] Launched batch of 50 vehicles.
# [Time 540.0 sec] Vehicle 372 re-routing from node 7198 due to congestion on edge 6878.
# [Time 540.0 sec] Vehicle 372 re-routing from node 7198 due to congestion on edge 6878.
# [Time 540.0 sec] Vehicle 372 re-routing from node 7198 due to congestion on edge 6878.
# [Time 540.0 sec] Vehicle 372 reached maximum re-route attempts at node 7198. Proceeding on current route.
# [Time 546.6 sec] Vehicle 320 re-routing from node 77491 due to congestion on edge 85959.
# [Time 546.6 sec] Vehicle 320 re-routing from node 77491 due to congestion on edge 85959.
# [Time 546.6 sec] Vehicle 320 re-routing from node 77491 due to congestion on edge 85959.
# [Time 546.6 sec] Vehicle 320 reached maximum re-route attempts at node 77491. Proceeding on current route.
# [Time 546.8 sec] Vehicle 52 reached destination 67578.
# [Time 548.8 sec] Vehicle 102 re-routing from node 43388 due to congestion on edge 80671_rev.
# [Time 551.6 sec] Vehicle 222 re-routing from node 47570 due to congestion on edge 95493.
# [Time 553.8 sec] Vehicle 389 re-routing from node 32782 due to congestion on edge 32594_rev.
# [Time 555.3 sec] Vehicle 84 reached destination 72403.
# [Time 558.3 sec] Vehicle 142 reached destination 68405.
# [Time 563.6 sec] Vehicle 318 re-routing from node 31404 due to congestion on edge 31494.
# [Time 567.7 sec] Vehicle 248 re-routing from node 32112 due to congestion on edge 31929_rev.
# [Time 572.0 sec] Vehicle 210 reached destination 33889.
# [Time 579.2 sec] Vehicle 356 re-routing from node 77491 due to congestion on edge 85959.
# [Time 579.2 sec] Vehicle 356 re-routing from node 77491 due to congestion on edge 85959.
# [Time 579.2 sec] Vehicle 356 re-routing from node 77491 due to congestion on edge 85959.
# [Time 579.2 sec] Vehicle 356 reached maximum re-route attempts at node 77491. Proceeding on current route.
# [Time 580.9 sec] Vehicle 197 re-routing from node 32112 due to congestion on edge 31929_rev.
# [Time 581.2 sec] Vehicle 190 re-routing from node 75611 due to congestion on edge 82521.
# [Time 581.2 sec] Vehicle 190 re-routing from node 75611 due to congestion on edge 82521.
# [Time 581.2 sec] Vehicle 190 re-routing from node 75611 due to congestion on edge 82521.
# [Time 581.2 sec] Vehicle 190 reached maximum re-route attempts at node 75611. Proceeding on current route.
# [Time 587.9 sec] Vehicle 126 reached destination 34014.
# [Time 593.2 sec] Vehicle 239 reached destination 76143.
# [Time 596.1 sec] Vehicle 175 reached destination 29252.
# [Time 596.5 sec] Vehicle 258 re-routing from node 29976 due to congestion on edge 29763.
# [Time 596.5 sec] Vehicle 36 reached destination 82463.
# [Sim Time 600.0 sec] Launched batch of 40 vehicles.
# [Time 601.4 sec] Vehicle 94 reached destination 45644.
# [Time 606.6 sec] Vehicle 97 re-routing from node 46008 due to congestion on edge 83061.
# [Time 606.6 sec] Vehicle 97 re-routing from node 46008 due to congestion on edge 83061.
# [Time 606.6 sec] Vehicle 97 re-routing from node 46008 due to congestion on edge 83061.
# [Time 606.6 sec] Vehicle 97 reached maximum re-route attempts at node 46008. Proceeding on current route.
# [Time 606.6 sec] Vehicle 83 re-routing from node 75611 due to congestion on edge 82521.
# [Time 607.2 sec] Vehicle 260 re-routing from node 42543 due to congestion on edge 70036.
# [Time 607.2 sec] Vehicle 260 re-routing from node 42543 due to congestion on edge 70036.
# [Time 607.2 sec] Vehicle 260 re-routing from node 42543 due to congestion on edge 70036.
# [Time 607.2 sec] Vehicle 260 reached maximum re-route attempts at node 42543. Proceeding on current route.
# [Time 607.5 sec] Vehicle 127 re-routing from node 75668 due to congestion on edge 82717.
# [Time 607.5 sec] Vehicle 127 re-routing from node 75668 due to congestion on edge 82717.
# [Time 607.5 sec] Vehicle 127 re-routing from node 75668 due to congestion on edge 82717.
# [Time 607.5 sec] Vehicle 127 reached maximum re-route attempts at node 75668. Proceeding on current route.
# [Time 610.9 sec] Vehicle 191 re-routing from node 81667 due to congestion on edge 95184.
# [Time 610.9 sec] Vehicle 191 re-routing from node 81667 due to congestion on edge 95184.
# [Time 610.9 sec] Vehicle 191 re-routing from node 81667 due to congestion on edge 95184.
# [Time 610.9 sec] Vehicle 191 reached maximum re-route attempts at node 81667. Proceeding on current route.
# [Time 613.0 sec] Vehicle 402 re-routing from node 70421 due to congestion on edge 73610_rev.
# [Time 613.0 sec] Vehicle 402 re-routing from node 70421 due to congestion on edge 73610_rev.
# [Time 613.0 sec] Vehicle 402 re-routing from node 70421 due to congestion on edge 73610_rev.
# [Time 613.0 sec] Vehicle 402 reached maximum re-route attempts at node 70421. Proceeding on current route.
# [Time 614.8 sec] Vehicle 308 re-routing from node 66110 due to congestion on edge 82716.
# [Time 614.8 sec] Vehicle 308 re-routing from node 66110 due to congestion on edge 82716.
# [Time 614.8 sec] Vehicle 308 re-routing from node 66110 due to congestion on edge 82716.
# [Time 614.8 sec] Vehicle 308 reached maximum re-route attempts at node 66110. Proceeding on current route.
# [Time 616.7 sec] Vehicle 386 re-routing from node 42543 due to congestion on edge 70036.
# [Time 616.7 sec] Vehicle 386 re-routing from node 42543 due to congestion on edge 70036.
# [Time 616.7 sec] Vehicle 386 re-routing from node 42543 due to congestion on edge 70036.
# [Time 616.7 sec] Vehicle 386 reached maximum re-route attempts at node 42543. Proceeding on current route.
# [Time 617.1 sec] Vehicle 117 re-routing from node 43871 due to congestion on edge 95861.
# [Time 619.4 sec] Vehicle 413 re-routing from node 33411 due to congestion on edge 78042_rev.
# [Time 620.6 sec] Vehicle 164 re-routing from node 66110 due to congestion on edge 82716.
# [Time 620.6 sec] Vehicle 164 re-routing from node 66110 due to congestion on edge 82716.
# [Time 620.6 sec] Vehicle 164 re-routing from node 66110 due to congestion on edge 82716.
# [Time 620.6 sec] Vehicle 164 reached maximum re-route attempts at node 66110. Proceeding on current route.
# [Time 623.7 sec] Vehicle 100 reached destination 28656.
# [Time 624.4 sec] Vehicle 270 re-routing from node 74768 due to congestion on edge 80337.
# [Time 628.7 sec] Vehicle 136 reached destination 28313.
# [Time 631.3 sec] Vehicle 227 reached destination 46088.
# [Time 632.6 sec] Vehicle 238 re-routing from node 77491 due to congestion on edge 85959.
# [Time 632.6 sec] Vehicle 238 re-routing from node 77491 due to congestion on edge 85959.
# [Time 632.6 sec] Vehicle 238 re-routing from node 77491 due to congestion on edge 85959.
# [Time 632.6 sec] Vehicle 238 reached maximum re-route attempts at node 77491. Proceeding on current route.
# [Time 636.1 sec] Vehicle 161 reached destination 49363.
# [Time 637.3 sec] Vehicle 321 re-routing from node 33411 due to congestion on edge 78042_rev.
# [Time 637.4 sec] Vehicle 249 re-routing from node 81758 due to congestion on edge 93214_rev.
# [Time 638.9 sec] Vehicle 133 re-routing from node 44173 due to congestion on edge 44779.
# [Time 639.8 sec] Vehicle 42 reached destination 43246.
# [Time 640.4 sec] Vehicle 235 re-routing from node 75611 due to congestion on edge 82521.
# [Time 642.0 sec] Vehicle 60 reached destination 29037.
# [Time 646.7 sec] Vehicle 185 reached destination 50586.
# [Time 647.9 sec] Vehicle 57 reached destination 38420.
# [Time 651.8 sec] Vehicle 153 re-routing from node 81667 due to congestion on edge 95184.
# [Time 651.8 sec] Vehicle 153 re-routing from node 81667 due to congestion on edge 95184.
# [Time 651.8 sec] Vehicle 153 re-routing from node 81667 due to congestion on edge 95184.
# [Time 651.8 sec] Vehicle 153 reached maximum re-route attempts at node 81667. Proceeding on current route.
# [Time 654.3 sec] Vehicle 24 reached destination 44585.
# [Time 656.5 sec] Vehicle 81 reached destination 34481.
# [Sim Time 660.0 sec] Launched batch of 50 vehicles.
# [Time 660.0 sec] Vehicle 440 re-routing from node 75620 due to congestion on edge 82561.
# [Time 660.0 sec] Vehicle 440 re-routing from node 75620 due to congestion on edge 82561.
# [Time 660.0 sec] Vehicle 440 re-routing from node 75620 due to congestion on edge 82561.
# [Time 660.0 sec] Vehicle 440 reached maximum re-route attempts at node 75620. Proceeding on current route.
# [Time 662.6 sec] Vehicle 456 re-routing from node 29455 due to congestion on edge 29291.
# [Time 666.8 sec] Vehicle 469 re-routing from node 32042 due to congestion on edge 86169_rev.
# [Time 667.7 sec] Vehicle 196 re-routing from node 46008 due to congestion on edge 83061.
# [Time 667.7 sec] Vehicle 196 re-routing from node 46008 due to congestion on edge 83061.
# [Time 667.7 sec] Vehicle 196 re-routing from node 46008 due to congestion on edge 83061.
# [Time 667.7 sec] Vehicle 196 reached maximum re-route attempts at node 46008. Proceeding on current route.
# [Time 669.1 sec] Vehicle 56 re-routing from node 48663 due to congestion on edge 49073_rev.
# [Time 673.4 sec] Vehicle 479 re-routing from node 32390 due to congestion on edge 32196_rev.
# [Time 680.6 sec] Vehicle 377 re-routing from node 81643 due to congestion on edge 92924.
# [Time 680.7 sec] Vehicle 69 reached destination 50571.
# [Time 681.1 sec] Vehicle 53 reached destination 73135.
# [Time 682.4 sec] Vehicle 257 reached destination 71691.
# [Time 685.2 sec] Vehicle 350 re-routing from node 75031 due to congestion on edge 80912.
# [Time 685.2 sec] Vehicle 350 re-routing from node 75031 due to congestion on edge 80912.
# [Time 685.2 sec] Vehicle 350 re-routing from node 75031 due to congestion on edge 80912.
# [Time 685.2 sec] Vehicle 350 reached maximum re-route attempts at node 75031. Proceeding on current route.
# [Time 686.3 sec] Vehicle 186 reached destination 31180.
# [Time 686.4 sec] Vehicle 90 reached destination 30529.
# [Time 686.9 sec] Vehicle 181 reached destination 44698.
# [Time 692.1 sec] Vehicle 46 reached destination 34699.
# [Time 692.3 sec] Vehicle 6 reached destination 73839.
# [Time 693.6 sec] Vehicle 432 re-routing from node 33729 due to congestion on edge 33592_rev.
# [Time 697.3 sec] Vehicle 273 re-routing from node 77491 due to congestion on edge 85959.
# [Time 697.3 sec] Vehicle 273 re-routing from node 77491 due to congestion on edge 85959.
# [Time 697.3 sec] Vehicle 273 re-routing from node 77491 due to congestion on edge 85959.
# [Time 697.3 sec] Vehicle 273 reached maximum re-route attempts at node 77491. Proceeding on current route.
# [Time 702.5 sec] Vehicle 141 reached destination 29268.
# [Time 704.1 sec] Vehicle 109 reached destination 33906.
# [Time 707.1 sec] Vehicle 144 re-routing from node 44992 due to congestion on edge 51864.
# [Time 708.7 sec] Vehicle 446 re-routing from node 43871 due to congestion on edge 95861.
# [Time 710.1 sec] Vehicle 219 reached destination 29386.
# [Time 716.7 sec] Vehicle 67 reached destination 49307.
# [Time 716.8 sec] Vehicle 326 re-routing from node 66110 due to congestion on edge 82716.
# [Time 716.8 sec] Vehicle 326 re-routing from node 66110 due to congestion on edge 82716.
# [Time 716.8 sec] Vehicle 326 re-routing from node 66110 due to congestion on edge 82716.
# [Time 716.8 sec] Vehicle 326 reached maximum re-route attempts at node 66110. Proceeding on current route.
# [Time 718.5 sec] Vehicle 25 reached destination 28458.
# [Time 719.5 sec] Vehicle 157 reached destination 30466.
# [Sim Time 720.0 sec] Launched batch of 20 vehicles.
# [Time 722.8 sec] Vehicle 189 reached destination 72354.
# [Time 723.0 sec] Vehicle 2 reached destination 76592.
# [Time 726.0 sec] Vehicle 298 re-routing from node 72052 due to congestion on edge 75783.
# [Time 726.0 sec] Vehicle 298 re-routing from node 72052 due to congestion on edge 75783.
# [Time 726.0 sec] Vehicle 298 re-routing from node 72052 due to congestion on edge 75783.
# [Time 726.0 sec] Vehicle 298 reached maximum re-route attempts at node 72052. Proceeding on current route.
# [Time 728.0 sec] Vehicle 104 reached destination 6391.
# [Time 730.0 sec] Vehicle 112 reached destination 42558.
# [Time 734.2 sec] Vehicle 431 re-routing from node 42530 due to congestion on edge 71632.
# [Time 734.6 sec] Vehicle 123 re-routing from node 44992 due to congestion on edge 51864.
# [Time 734.6 sec] Vehicle 123 re-routing from node 44992 due to congestion on edge 51864.
# [Time 734.6 sec] Vehicle 123 re-routing from node 44992 due to congestion on edge 51864.
# [Time 734.6 sec] Vehicle 123 reached maximum re-route attempts at node 44992. Proceeding on current route.
# [Time 735.2 sec] Vehicle 120 reached destination 75177.
# [Time 736.5 sec] Vehicle 202 reached destination 74277.
# [Time 740.3 sec] Vehicle 151 reached destination 48671.
# [Time 745.2 sec] Vehicle 383 re-routing from node 44992 due to congestion on edge 51864.
# [Time 745.2 sec] Vehicle 383 re-routing from node 44992 due to congestion on edge 51864.
# [Time 745.2 sec] Vehicle 383 re-routing from node 44992 due to congestion on edge 51864.
# [Time 745.2 sec] Vehicle 383 reached maximum re-route attempts at node 44992. Proceeding on current route.
# [Time 747.0 sec] Vehicle 454 re-routing from node 44636 due to congestion on edge 44350.
# [Time 747.0 sec] Vehicle 454 re-routing from node 44636 due to congestion on edge 44350.
# [Time 747.0 sec] Vehicle 454 re-routing from node 44636 due to congestion on edge 44350.
# [Time 747.0 sec] Vehicle 454 reached maximum re-route attempts at node 44636. Proceeding on current route.
# [Time 747.1 sec] Vehicle 156 re-routing from node 44639 due to congestion on edge 44351_rev.
# [Time 747.1 sec] Vehicle 156 re-routing from node 44639 due to congestion on edge 44351_rev.
# [Time 747.1 sec] Vehicle 156 re-routing from node 44639 due to congestion on edge 44351_rev.
# [Time 747.1 sec] Vehicle 156 reached maximum re-route attempts at node 44639. Proceeding on current route.
# [Time 747.2 sec] Vehicle 376 re-routing from node 77491 due to congestion on edge 85959.
# [Time 747.2 sec] Vehicle 376 re-routing from node 77491 due to congestion on edge 85959.
# [Time 747.2 sec] Vehicle 376 re-routing from node 77491 due to congestion on edge 85959.
# [Time 747.2 sec] Vehicle 376 reached maximum re-route attempts at node 77491. Proceeding on current route.
# [Time 748.8 sec] Vehicle 213 reached destination 29488.
# [Time 748.9 sec] Vehicle 195 reached destination 72273.
# [Time 755.0 sec] Vehicle 88 reached destination 34292.
# [Time 758.2 sec] Vehicle 282 reached destination 33461.
# [Time 758.4 sec] Vehicle 168 re-routing from node 75668 due to congestion on edge 82717.
# [Time 758.4 sec] Vehicle 168 re-routing from node 75668 due to congestion on edge 82717.
# [Time 758.4 sec] Vehicle 168 re-routing from node 75668 due to congestion on edge 82717.
# [Time 758.4 sec] Vehicle 168 reached maximum re-route attempts at node 75668. Proceeding on current route.
# [Time 761.2 sec] Vehicle 286 reached destination 33308.
# [Time 762.4 sec] Vehicle 176 reached destination 42072.
# [Time 768.8 sec] Vehicle 387 re-routing from node 77491 due to congestion on edge 85959.
# [Time 768.8 sec] Vehicle 387 re-routing from node 77491 due to congestion on edge 85959.
# [Time 768.8 sec] Vehicle 387 re-routing from node 77491 due to congestion on edge 85959.
# [Time 768.8 sec] Vehicle 387 reached maximum re-route attempts at node 77491. Proceeding on current route.
# [Time 769.2 sec] Vehicle 172 re-routing from node 48662 due to congestion on edge 49073.
# [Time 771.9 sec] Vehicle 364 re-routing from node 68319 due to congestion on edge 84583_rev.
# [Time 772.8 sec] Vehicle 139 reached destination 34004.
# [Time 773.5 sec] Vehicle 374 re-routing from node 31637 due to congestion on edge 82702.
# [Time 776.9 sec] Vehicle 301 re-routing from node 74337 due to congestion on edge 79185.
# [Sim Time 780.0 sec] Launched batch of 40 vehicles.
# [Time 780.0 sec] Vehicle 534 re-routing from node 33469 due to congestion on edge 34363_rev.
# [Time 780.4 sec] Vehicle 483 re-routing from node 32884 due to congestion on edge 32751.
# [Time 783.0 sec] Vehicle 306 re-routing from node 66110 due to congestion on edge 82716.
# [Time 783.0 sec] Vehicle 306 re-routing from node 66110 due to congestion on edge 82716.
# [Time 783.0 sec] Vehicle 306 re-routing from node 66110 due to congestion on edge 82716.
# [Time 783.0 sec] Vehicle 306 reached maximum re-route attempts at node 66110. Proceeding on current route.
# [Time 783.2 sec] Vehicle 71 reached destination 27847.
# [Time 783.9 sec] Vehicle 125 reached destination 30968.
# [Time 784.4 sec] Vehicle 334 reached destination 71006.
# [Time 786.7 sec] Vehicle 255 re-routing from node 44992 due to congestion on edge 51864.
# [Time 788.1 sec] Vehicle 78 reached destination 30077.
# [Time 788.7 sec] Vehicle 228 reached destination 7281.
# [Time 789.1 sec] Vehicle 72 reached destination 81950.
# [Time 790.0 sec] Vehicle 533 re-routing from node 39246 due to congestion on edge 39084_rev.
# [Time 790.1 sec] Vehicle 393 re-routing from node 66110 due to congestion on edge 82716.
# [Time 790.1 sec] Vehicle 393 re-routing from node 66110 due to congestion on edge 82716.
# [Time 790.1 sec] Vehicle 393 re-routing from node 66110 due to congestion on edge 82716.
# [Time 790.1 sec] Vehicle 393 reached maximum re-route attempts at node 66110. Proceeding on current route.
# [Time 792.0 sec] Vehicle 133 reached destination 52524.
# [Time 796.6 sec] Vehicle 289 reached destination 30385.
# [Time 796.9 sec] Vehicle 384 reached destination 46152.
# [Time 807.3 sec] Vehicle 103 reached destination 70718.
# [Time 808.9 sec] Vehicle 31 reached destination 31799.
# [Time 810.0 sec] Vehicle 297 re-routing from node 45490 due to congestion on edge 45347_rev.
# [Time 810.2 sec] Vehicle 156 reached destination 78341.
# [Time 812.9 sec] Vehicle 250 reached destination 33700.
# [Time 814.4 sec] Vehicle 362 re-routing from node 75031 due to congestion on edge 80912.
# [Time 814.4 sec] Vehicle 362 re-routing from node 75031 due to congestion on edge 80912.
# [Time 814.4 sec] Vehicle 362 re-routing from node 75031 due to congestion on edge 80912.
# [Time 814.4 sec] Vehicle 362 reached maximum re-route attempts at node 75031. Proceeding on current route.
# [Time 816.5 sec] Vehicle 469 re-routing from node 71817 due to congestion on edge 89713.
# [Time 816.5 sec] Vehicle 469 re-routing from node 71817 due to congestion on edge 89713.
# [Time 816.5 sec] Vehicle 469 re-routing from node 71817 due to congestion on edge 89713.
# [Time 816.5 sec] Vehicle 469 reached maximum re-route attempts at node 71817. Proceeding on current route.
# [Time 818.8 sec] Vehicle 62 reached destination 30615.
# [Time 819.1 sec] Vehicle 406 reached destination 67975.
# [Time 819.5 sec] Vehicle 55 reached destination 34239.
# [Time 819.8 sec] Vehicle 266 reached destination 69235.
# [Time 820.3 sec] Vehicle 236 reached destination 33131.
# [Time 821.3 sec] Vehicle 260 reached destination 44739.
# [Time 821.6 sec] Vehicle 244 reached destination 67911.
# [Time 823.3 sec] Vehicle 452 re-routing from node 29083 due to congestion on edge 83588.
# [Time 825.3 sec] Vehicle 179 re-routing from node 67739 due to congestion on edge 78824.
# [Time 825.3 sec] Vehicle 179 re-routing from node 67739 due to congestion on edge 78824.
# [Time 825.3 sec] Vehicle 179 re-routing from node 67739 due to congestion on edge 78824.
# [Time 825.3 sec] Vehicle 179 reached maximum re-route attempts at node 67739. Proceeding on current route.
# [Time 827.6 sec] Vehicle 333 re-routing from node 67739 due to congestion on edge 78824.
# [Time 827.6 sec] Vehicle 333 re-routing from node 67739 due to congestion on edge 78824.
# [Time 827.6 sec] Vehicle 333 re-routing from node 67739 due to congestion on edge 78824.
# [Time 827.6 sec] Vehicle 333 reached maximum re-route attempts at node 67739. Proceeding on current route.
# [Time 828.9 sec] Vehicle 484 re-routing from node 68319 due to congestion on edge 84583_rev.
# [Time 830.2 sec] Vehicle 311 reached destination 34250.
# [Time 834.0 sec] Vehicle 422 re-routing from node 46008 due to congestion on edge 83061.
# [Time 834.0 sec] Vehicle 422 re-routing from node 46008 due to congestion on edge 83061.
# [Time 834.0 sec] Vehicle 422 re-routing from node 46008 due to congestion on edge 83061.
# [Time 834.0 sec] Vehicle 422 reached maximum re-route attempts at node 46008. Proceeding on current route.
# [Time 834.0 sec] Vehicle 318 reached destination 64598.
# [Time 834.0 sec] Vehicle 101 reached destination 28696.
# [Time 834.2 sec] Vehicle 108 reached destination 28407.
# [Time 835.3 sec] Vehicle 302 re-routing from node 70800 due to congestion on edge 95163.
# [Time 835.3 sec] Vehicle 302 re-routing from node 70800 due to congestion on edge 95163.
# [Time 835.3 sec] Vehicle 302 re-routing from node 70800 due to congestion on edge 95163.
# [Time 835.3 sec] Vehicle 302 reached maximum re-route attempts at node 70800. Proceeding on current route.
# [Time 837.0 sec] Vehicle 222 reached destination 28301.
# [Sim Time 840.0 sec] Launched batch of 40 vehicles.
# [Time 840.2 sec] Vehicle 531 re-routing from node 70800 due to congestion on edge 95163.
# [Time 840.2 sec] Vehicle 531 re-routing from node 70800 due to congestion on edge 95163.
# [Time 840.2 sec] Vehicle 531 re-routing from node 70800 due to congestion on edge 95163.
# [Time 840.2 sec] Vehicle 531 reached maximum re-route attempts at node 70800. Proceeding on current route.
# [Time 842.1 sec] Vehicle 307 reached destination 46043.
# [Time 842.6 sec] Vehicle 573 re-routing from node 29455 due to congestion on edge 29291.
# [Time 842.7 sec] Vehicle 165 reached destination 30096.
# [Time 845.0 sec] Vehicle 515 re-routing from node 68319 due to congestion on edge 84583_rev.
# [Time 847.5 sec] Vehicle 284 reached destination 48663.
# [Time 849.0 sec] Vehicle 148 re-routing from node 66635 due to congestion on edge 67904.
# [Time 849.4 sec] Vehicle 303 reached destination 31616.
# [Time 849.5 sec] Vehicle 438 reached destination 33945.
# [Time 850.5 sec] Vehicle 278 reached destination 30828.
# [Time 850.9 sec] Vehicle 262 re-routing from node 77498 due to congestion on edge 88020_rev.
# [Time 850.9 sec] Vehicle 262 re-routing from node 77498 due to congestion on edge 88020_rev.
# [Time 850.9 sec] Vehicle 262 re-routing from node 77498 due to congestion on edge 88020_rev.
# [Time 850.9 sec] Vehicle 262 reached maximum re-route attempts at node 77498. Proceeding on current route.
# [Time 851.2 sec] Vehicle 56 reached destination 29925.
# [Time 853.4 sec] Vehicle 183 reached destination 34467.
# [Time 854.3 sec] Vehicle 107 re-routing from node 44992 due to congestion on edge 51864.
# [Time 855.8 sec] Vehicle 461 reached destination 44608.
# [Time 857.9 sec] Vehicle 328 re-routing from node 67739 due to congestion on edge 78824.
# [Time 857.9 sec] Vehicle 328 re-routing from node 67739 due to congestion on edge 78824.
# [Time 857.9 sec] Vehicle 328 re-routing from node 67739 due to congestion on edge 78824.
# [Time 857.9 sec] Vehicle 328 reached maximum re-route attempts at node 67739. Proceeding on current route.
# [Time 858.2 sec] Vehicle 355 re-routing from node 70800 due to congestion on edge 95163.
# [Time 858.2 sec] Vehicle 355 re-routing from node 70800 due to congestion on edge 95163.
# [Time 858.2 sec] Vehicle 355 re-routing from node 70800 due to congestion on edge 95163.
# [Time 858.2 sec] Vehicle 355 reached maximum re-route attempts at node 70800. Proceeding on current route.
# [Time 859.9 sec] Vehicle 220 reached destination 81951.
# [Time 861.3 sec] Vehicle 97 reached destination 28939.
# [Time 862.9 sec] Vehicle 30 reached destination 31004.
# [Time 863.9 sec] Vehicle 243 reached destination 31877.
# [Time 866.0 sec] Vehicle 267 reached destination 44246.
# [Time 866.6 sec] Vehicle 321 reached destination 45657.
# [Time 868.4 sec] Vehicle 527 re-routing from node 43871 due to congestion on edge 95861.
# [Time 868.4 sec] Vehicle 363 reached destination 76732.
# [Time 869.1 sec] Vehicle 575 re-routing from node 32884 due to congestion on edge 32751.
# [Time 870.0 sec] Vehicle 419 re-routing from node 31404 due to congestion on edge 31221.
# [Time 871.3 sec] Vehicle 166 reached destination 79893.
# [Time 872.3 sec] Vehicle 201 reached destination 72758.
# [Time 873.7 sec] Vehicle 268 reached destination 33649.
# [Time 873.9 sec] Vehicle 253 re-routing from node 30319 due to congestion on edge 30222.
# [Time 874.4 sec] Vehicle 196 reached destination 30257.
# [Time 876.1 sec] Vehicle 324 reached destination 44539.
# [Time 878.2 sec] Vehicle 160 reached destination 31899.
# [Time 878.8 sec] Vehicle 409 re-routing from node 75059 due to congestion on edge 80998.
# [Time 879.9 sec] Vehicle 357 re-routing from node 46008 due to congestion on edge 83061.
# [Time 879.9 sec] Vehicle 357 re-routing from node 46008 due to congestion on edge 83061.
# [Time 879.9 sec] Vehicle 357 re-routing from node 46008 due to congestion on edge 83061.
# [Time 879.9 sec] Vehicle 357 reached maximum re-route attempts at node 46008. Proceeding on current route.
# [Time 880.8 sec] Vehicle 391 reached destination 82302.
# [Time 882.1 sec] Vehicle 325 re-routing from node 67739 due to congestion on edge 78824.
# [Time 882.1 sec] Vehicle 325 re-routing from node 67739 due to congestion on edge 78824.
# [Time 882.1 sec] Vehicle 325 re-routing from node 67739 due to congestion on edge 78824.
# [Time 882.1 sec] Vehicle 325 reached maximum re-route attempts at node 67739. Proceeding on current route.
# [Time 882.9 sec] Vehicle 310 reached destination 64783.
# [Time 885.0 sec] Vehicle 19 reached destination 46259.
# [Time 886.9 sec] Vehicle 338 reached destination 30550.
# [Time 890.1 sec] Vehicle 264 re-routing from node 76884 due to congestion on edge 84906_rev.
# [Time 890.5 sec] Vehicle 277 re-routing from node 72052 due to congestion on edge 75783.
# [Time 890.5 sec] Vehicle 277 re-routing from node 72052 due to congestion on edge 75783.
# [Time 890.5 sec] Vehicle 277 re-routing from node 72052 due to congestion on edge 75783.
# [Time 890.5 sec] Vehicle 277 reached maximum re-route attempts at node 72052. Proceeding on current route.
# [Time 891.3 sec] Vehicle 435 re-routing from node 67739 due to congestion on edge 78824.
# [Time 891.3 sec] Vehicle 435 re-routing from node 67739 due to congestion on edge 78824.
# [Time 891.3 sec] Vehicle 435 re-routing from node 67739 due to congestion on edge 78824.
# [Time 891.3 sec] Vehicle 435 reached maximum re-route attempts at node 67739. Proceeding on current route.
# [Time 893.0 sec] Vehicle 204 reached destination 42137.
# [Time 894.1 sec] Vehicle 333 re-routing from node 46008 due to congestion on edge 83061.
# [Time 894.1 sec] Vehicle 333 re-routing from node 46008 due to congestion on edge 83061.
# [Time 894.1 sec] Vehicle 333 re-routing from node 46008 due to congestion on edge 83061.
# [Time 894.1 sec] Vehicle 333 reached maximum re-route attempts at node 46008. Proceeding on current route.
# [Time 894.7 sec] Vehicle 526 re-routing from node 43871 due to congestion on edge 95861.
# [Time 897.4 sec] Vehicle 554 re-routing from node 67739 due to congestion on edge 78824.
# [Time 897.4 sec] Vehicle 554 re-routing from node 67739 due to congestion on edge 78824.
# [Time 897.4 sec] Vehicle 554 re-routing from node 67739 due to congestion on edge 78824.
# [Time 897.4 sec] Vehicle 554 reached maximum re-route attempts at node 67739. Proceeding on current route.
# [Time 898.6 sec] Vehicle 389 reached destination 81601.
# [Time 899.7 sec] Vehicle 158 reached destination 49371.
# [Sim Time 900.0 sec] Launched batch of 20 vehicles.
# [Time 900.0 sec] Vehicle 470 reached destination 79009.
# [Time 903.2 sec] Vehicle 574 re-routing from node 46626 due to congestion on edge 88840.
# [Time 903.7 sec] Vehicle 373 re-routing from node 70800 due to congestion on edge 95163.
# [Time 903.7 sec] Vehicle 373 re-routing from node 70800 due to congestion on edge 95163.
# [Time 903.7 sec] Vehicle 373 re-routing from node 70800 due to congestion on edge 95163.
# [Time 903.7 sec] Vehicle 373 reached maximum re-route attempts at node 70800. Proceeding on current route.
# [Time 904.0 sec] Vehicle 116 reached destination 33721.
# [Time 905.4 sec] Vehicle 205 reached destination 49058.
# [Time 905.5 sec] Vehicle 192 re-routing from node 29437 due to congestion on edge 29272_rev.
# [Time 906.3 sec] Vehicle 442 re-routing from node 81643 due to congestion on edge 92924.
# [Time 906.9 sec] Vehicle 275 re-routing from node 66110 due to congestion on edge 82716.
# [Time 906.9 sec] Vehicle 275 re-routing from node 66110 due to congestion on edge 82716.
# [Time 906.9 sec] Vehicle 275 re-routing from node 66110 due to congestion on edge 82716.
# [Time 906.9 sec] Vehicle 275 reached maximum re-route attempts at node 66110. Proceeding on current route.
# [Time 908.0 sec] Vehicle 28 reached destination 29719.
# [Time 908.5 sec] Vehicle 400 re-routing from node 70800 due to congestion on edge 95163.
# [Time 908.5 sec] Vehicle 400 re-routing from node 70800 due to congestion on edge 95163.
# [Time 908.5 sec] Vehicle 400 re-routing from node 70800 due to congestion on edge 95163.
# [Time 908.5 sec] Vehicle 400 reached maximum re-route attempts at node 70800. Proceeding on current route.
# [Time 909.5 sec] Vehicle 131 reached destination 34159.
# [Time 909.7 sec] Vehicle 430 reached destination 81191.
# [Time 910.4 sec] Vehicle 405 re-routing from node 48663 due to congestion on edge 49073_rev.
# [Time 910.9 sec] Vehicle 353 re-routing from node 47565 due to congestion on edge 93602_rev.
# [Time 911.8 sec] Vehicle 414 re-routing from node 33826 due to congestion on edge 33684.
# [Time 914.0 sec] Vehicle 47 reached destination 39294.
# [Time 914.2 sec] Vehicle 544 re-routing from node 78006 due to congestion on edge 90805_rev.
# [Time 915.4 sec] Vehicle 242 re-routing from node 67739 due to congestion on edge 78824.
# [Time 915.4 sec] Vehicle 242 re-routing from node 67739 due to congestion on edge 78824.
# [Time 915.4 sec] Vehicle 242 re-routing from node 67739 due to congestion on edge 78824.
# [Time 915.4 sec] Vehicle 242 reached maximum re-route attempts at node 67739. Proceeding on current route.
# [Time 916.2 sec] Vehicle 66 reached destination 71363.
# [Time 921.9 sec] Vehicle 149 reached destination 76740.
# [Time 923.4 sec] Vehicle 214 reached destination 34548.
# [Time 926.2 sec] Vehicle 525 re-routing from node 33826 due to congestion on edge 33684.
# [Time 926.3 sec] Vehicle 464 reached destination 83342.
# [Time 926.5 sec] Vehicle 546 re-routing from node 77491 due to congestion on edge 85959.
# [Time 926.5 sec] Vehicle 546 re-routing from node 77491 due to congestion on edge 85959.
# [Time 926.5 sec] Vehicle 546 re-routing from node 77491 due to congestion on edge 85959.
# [Time 926.5 sec] Vehicle 546 reached maximum re-route attempts at node 77491. Proceeding on current route.
# [Time 927.9 sec] Vehicle 502 re-routing from node 81643 due to congestion on edge 92924.
# [Time 930.7 sec] Vehicle 5 reached destination 45842.
# [Time 931.1 sec] Vehicle 281 reached destination 30496.
# [Time 931.3 sec] Vehicle 576 re-routing from node 32889 due to congestion on edge 80678.
# [Time 931.3 sec] Vehicle 576 re-routing from node 32889 due to congestion on edge 80678.
# [Time 931.3 sec] Vehicle 576 re-routing from node 32889 due to congestion on edge 80678.
# [Time 931.3 sec] Vehicle 576 reached maximum re-route attempts at node 32889. Proceeding on current route.
# [Time 931.9 sec] Vehicle 233 re-routing from node 33827 due to congestion on edge 33684_rev.
# [Time 934.3 sec] Vehicle 434 re-routing from node 32889 due to congestion on edge 80678.
# [Time 934.3 sec] Vehicle 434 re-routing from node 32889 due to congestion on edge 80678.
# [Time 934.3 sec] Vehicle 434 re-routing from node 32889 due to congestion on edge 80678.
# [Time 934.3 sec] Vehicle 434 reached maximum re-route attempts at node 32889. Proceeding on current route.
# [Time 934.8 sec] Vehicle 39 reached destination 65904.
# [Time 934.9 sec] Vehicle 595 re-routing from node 46626 due to congestion on edge 88840.
# [Time 938.4 sec] Vehicle 316 re-routing from node 67739 due to congestion on edge 78824.
# [Time 938.4 sec] Vehicle 316 re-routing from node 67739 due to congestion on edge 78824.
# [Time 938.4 sec] Vehicle 316 re-routing from node 67739 due to congestion on edge 78824.
# [Time 938.4 sec] Vehicle 316 reached maximum re-route attempts at node 67739. Proceeding on current route.
# [Time 940.2 sec] Vehicle 172 reached destination 66678.
# [Time 944.0 sec] Vehicle 297 reached destination 33056.
# [Time 945.1 sec] Vehicle 347 re-routing from node 45490 due to congestion on edge 45347_rev.
# [Time 945.5 sec] Vehicle 95 reached destination 39262.
# [Time 945.5 sec] Vehicle 580 re-routing from node 48639 due to congestion on edge 49050.
# [Time 946.4 sec] Vehicle 305 re-routing from node 33826 due to congestion on edge 33684.
# [Time 947.0 sec] Vehicle 549 re-routing from node 70800 due to congestion on edge 95163.
# [Time 947.0 sec] Vehicle 549 re-routing from node 70800 due to congestion on edge 95163.
# [Time 947.0 sec] Vehicle 549 re-routing from node 70800 due to congestion on edge 95163.
# [Time 947.0 sec] Vehicle 549 reached maximum re-route attempts at node 70800. Proceeding on current route.
# [Time 948.4 sec] Vehicle 280 reached destination 34736.
# [Time 948.9 sec] Vehicle 432 reached destination 45298.
# [Time 950.8 sec] Vehicle 429 reached destination 31947.
# [Time 951.6 sec] Vehicle 558 re-routing from node 32889 due to congestion on edge 80678.
# [Time 951.6 sec] Vehicle 558 re-routing from node 32889 due to congestion on edge 80678.
# [Time 951.6 sec] Vehicle 558 re-routing from node 32889 due to congestion on edge 80678.
# [Time 951.6 sec] Vehicle 558 reached maximum re-route attempts at node 32889. Proceeding on current route.
# [Time 952.2 sec] Vehicle 198 reached destination 30570.
# [Time 952.7 sec] Vehicle 211 re-routing from node 33827 due to congestion on edge 33684_rev.
# [Time 953.1 sec] Vehicle 79 reached destination 32776.
# [Time 953.5 sec] Vehicle 38 reached destination 27871.
# [Time 954.2 sec] Vehicle 224 reached destination 42412.
# [Time 959.4 sec] Vehicle 515 re-routing from node 32112 due to congestion on edge 31929_rev.
# [Time 959.9 sec] Vehicle 265 reached destination 70797.
# [Sim Time 960.0 sec] Launched batch of 40 vehicles.
# [Time 960.5 sec] Vehicle 140 reached destination 6480.
# [Time 960.7 sec] Vehicle 254 re-routing from node 34062 due to congestion on edge 33918_rev.
# [Time 960.7 sec] Vehicle 254 re-routing from node 34062 due to congestion on edge 33918_rev.
# [Time 960.7 sec] Vehicle 254 re-routing from node 34062 due to congestion on edge 33918_rev.
# [Time 960.7 sec] Vehicle 254 reached maximum re-route attempts at node 34062. Proceeding on current route.
# [Time 961.1 sec] Vehicle 240 re-routing from node 33827 due to congestion on edge 33684_rev.
# [Time 961.5 sec] Vehicle 234 re-routing from node 66110 due to congestion on edge 82716.
# [Time 961.5 sec] Vehicle 234 re-routing from node 66110 due to congestion on edge 82716.
# [Time 961.5 sec] Vehicle 234 re-routing from node 66110 due to congestion on edge 82716.
# [Time 961.5 sec] Vehicle 234 reached maximum re-route attempts at node 66110. Proceeding on current route.
# [Time 963.2 sec] Vehicle 119 reached destination 34061.
# [Time 964.8 sec] Vehicle 325 reached destination 69027.
# [Time 966.0 sec] Vehicle 441 reached destination 33144.
# [Time 966.9 sec] Vehicle 483 re-routing from node 32889 due to congestion on edge 80678.
# [Time 966.9 sec] Vehicle 483 re-routing from node 32889 due to congestion on edge 80678.
# [Time 966.9 sec] Vehicle 483 re-routing from node 32889 due to congestion on edge 80678.
# [Time 966.9 sec] Vehicle 483 reached maximum re-route attempts at node 32889. Proceeding on current route.
# [Time 968.1 sec] Vehicle 115 reached destination 74179.
# [Time 970.4 sec] Vehicle 87 reached destination 28337.
# [Time 972.8 sec] Vehicle 539 re-routing from node 77491 due to congestion on edge 85959.
# ...
# [Time 21371.8 sec] Vehicle 9768 reached destination 47606.
# [Time 21372.6 sec] Vehicle 9857 re-routing from node 31404 due to congestion on edge 31494.
# [Time 21372.6 sec] Vehicle 9857 re-routing from node 31404 due to congestion on edge 31221.
# [Time 21372.6 sec] Vehicle 9857 re-routing from node 31404 due to congestion on edge 31221.
# [Time 21372.6 sec] Vehicle 9857 reached maximum re-route attempts at node 31404. Proceeding on current route.
# [Time 21374.9 sec] Vehicle 9843 reached destination 30769.
# [Time 21376.2 sec] Vehicle 9431 reached destination 81783.
# [Time 21377.9 sec] Vehicle 9916 re-routing from node 48826 due to congestion on edge 49271.
# [Time 21378.8 sec] Vehicle 9361 re-routing from node 71364 due to congestion on edge 74867.
# [Time 21380.7 sec] Vehicle 9795 reached destination 32574.
# [Time 21382.8 sec] Vehicle 9337 re-routing from node 31404 due to congestion on edge 31221.
# [Time 21382.8 sec] Vehicle 9337 re-routing from node 31404 due to congestion on edge 31494.
# [Time 21382.8 sec] Vehicle 9337 re-routing from node 31404 due to congestion on edge 31494.
# [Time 21382.8 sec] Vehicle 9337 reached maximum re-route attempts at node 31404. Proceeding on current route.
# [Time 21384.3 sec] Vehicle 9926 re-routing from node 42069 due to congestion on edge 41808.
# [Time 21384.3 sec] Vehicle 9926 re-routing from node 42069 due to congestion on edge 41808.
# [Time 21384.3 sec] Vehicle 9926 re-routing from node 42069 due to congestion on edge 41808.
# [Time 21384.3 sec] Vehicle 9926 reached maximum re-route attempts at node 42069. Proceeding on current route.
# [Time 21389.0 sec] Vehicle 1285 reached destination 43277.
# [Time 21400.5 sec] Vehicle 8226 reached destination 34626.
# [Time 21401.3 sec] Vehicle 63 reached destination 83175.
# [Time 21405.0 sec] Vehicle 9585 reached destination 42605.
# [Time 21407.0 sec] Vehicle 9903 re-routing from node 33480 due to congestion on edge 46710.
# [Time 21407.0 sec] Vehicle 9903 re-routing from node 33480 due to congestion on edge 46710.
# [Time 21407.0 sec] Vehicle 9903 re-routing from node 33480 due to congestion on edge 46710.
# [Time 21407.0 sec] Vehicle 9903 reached maximum re-route attempts at node 33480. Proceeding on current route.
# [Time 21408.2 sec] Vehicle 9624 reached destination 48428.
# [Time 21409.3 sec] Vehicle 9817 reached destination 66104.
# [Time 21410.8 sec] Vehicle 9864 re-routing from node 44183 due to congestion on edge 43892.
# [Time 21410.8 sec] Vehicle 9864 re-routing from node 44183 due to congestion on edge 43892.
# [Time 21410.8 sec] Vehicle 9864 re-routing from node 44183 due to congestion on edge 43892.
# [Time 21410.8 sec] Vehicle 9864 reached maximum re-route attempts at node 44183. Proceeding on current route.
# [Time 21412.2 sec] Vehicle 9813 re-routing from node 78626 due to congestion on edge 88031_rev.
# [Time 21412.2 sec] Vehicle 9813 re-routing from node 78626 due to congestion on edge 88031_rev.
# [Time 21412.2 sec] Vehicle 9813 re-routing from node 78626 due to congestion on edge 88031_rev.
# [Time 21412.2 sec] Vehicle 9813 reached maximum re-route attempts at node 78626. Proceeding on current route.
# [Time 21414.6 sec] Vehicle 9549 reached destination 33276.
# [Sim Time 21420.0 sec] Launched batch of 10 vehicles.
# [Time 21426.3 sec] Vehicle 9899 re-routing from node 74768 due to congestion on edge 80337.
# [Time 21426.9 sec] Vehicle 9930 re-routing from node 68759 due to congestion on edge 70998_rev.
# [Time 21430.2 sec] Vehicle 9923 re-routing from node 29841 due to congestion on edge 85958.
# [Time 21430.2 sec] Vehicle 9923 re-routing from node 29841 due to congestion on edge 85958.
# [Time 21430.2 sec] Vehicle 9923 re-routing from node 29841 due to congestion on edge 85958.
# [Time 21430.2 sec] Vehicle 9923 reached maximum re-route attempts at node 29841. Proceeding on current route.
# [Time 21432.3 sec] Vehicle 9361 reached destination 80753.
# [Time 21433.0 sec] Vehicle 9853 reached destination 38510.
# [Time 21434.0 sec] Vehicle 9907 re-routing from node 75031 due to congestion on edge 80912.
# [Time 21434.0 sec] Vehicle 9907 re-routing from node 75031 due to congestion on edge 80912.
# [Time 21434.0 sec] Vehicle 9907 re-routing from node 75031 due to congestion on edge 80912.
# [Time 21434.0 sec] Vehicle 9907 reached maximum re-route attempts at node 75031. Proceeding on current route.
# [Time 21434.5 sec] Vehicle 9882 reached destination 72631.
# [Time 21434.5 sec] Vehicle 9833 re-routing from node 48829 due to congestion on edge 82550.
# [Time 21437.2 sec] Vehicle 9917 re-routing from node 33480 due to congestion on edge 46710.
# [Time 21437.2 sec] Vehicle 9917 re-routing from node 33480 due to congestion on edge 46710.
# [Time 21437.2 sec] Vehicle 9917 re-routing from node 33480 due to congestion on edge 46710.
# [Time 21437.2 sec] Vehicle 9917 reached maximum re-route attempts at node 33480. Proceeding on current route.
# [Time 21439.7 sec] Vehicle 9866 reached destination 76728.
# [Time 21449.8 sec] Vehicle 9738 reached destination 34111.
# [Time 21450.7 sec] Vehicle 9862 re-routing from node 31404 due to congestion on edge 31221.
# [Time 21450.7 sec] Vehicle 9862 re-routing from node 31404 due to congestion on edge 31221.
# [Time 21450.7 sec] Vehicle 9862 re-routing from node 31404 due to congestion on edge 31221.
# [Time 21450.7 sec] Vehicle 9862 reached maximum re-route attempts at node 31404. Proceeding on current route.
# [Time 21455.2 sec] Vehicle 9714 reached destination 34065.
# [Time 21460.9 sec] Vehicle 9887 re-routing from node 81667 due to congestion on edge 95184.
# [Time 21460.9 sec] Vehicle 9887 re-routing from node 81667 due to congestion on edge 95184.
# [Time 21460.9 sec] Vehicle 9887 re-routing from node 81667 due to congestion on edge 95184.
# [Time 21460.9 sec] Vehicle 9887 reached maximum re-route attempts at node 81667. Proceeding on current route.
# [Time 21460.9 sec] Vehicle 9909 re-routing from node 70800 due to congestion on edge 95163.
# [Time 21460.9 sec] Vehicle 9909 re-routing from node 70800 due to congestion on edge 95163.
# [Time 21460.9 sec] Vehicle 9909 re-routing from node 70800 due to congestion on edge 95163.
# [Time 21460.9 sec] Vehicle 9909 reached maximum re-route attempts at node 70800. Proceeding on current route.
# [Time 21462.0 sec] Vehicle 9700 reached destination 77655.
# [Time 21466.8 sec] Vehicle 9789 reached destination 29988.
# [Time 21467.5 sec] Vehicle 9675 re-routing from node 44904 due to congestion on edge 78936.
# [Time 21467.5 sec] Vehicle 9675 re-routing from node 44904 due to congestion on edge 78936.
# [Time 21467.5 sec] Vehicle 9675 re-routing from node 44904 due to congestion on edge 78936.
# [Time 21467.5 sec] Vehicle 9675 reached maximum re-route attempts at node 44904. Proceeding on current route.
# [Time 21469.2 sec] Vehicle 9929 re-routing from node 48808 due to congestion on edge 49245.
# [Time 21469.2 sec] Vehicle 9929 re-routing from node 48808 due to congestion on edge 49245.
# [Time 21469.2 sec] Vehicle 9929 re-routing from node 48808 due to congestion on edge 49245.
# [Time 21469.2 sec] Vehicle 9929 reached maximum re-route attempts at node 48808. Proceeding on current route.
# [Time 21469.3 sec] Vehicle 9810 reached destination 31838.
# [Time 21471.0 sec] Vehicle 9919 re-routing from node 74081 due to congestion on edge 78837_rev.
# [Time 21472.1 sec] Vehicle 9930 re-routing from node 29841 due to congestion on edge 85958.
# [Time 21472.1 sec] Vehicle 9930 re-routing from node 29841 due to congestion on edge 85958.
# [Time 21472.1 sec] Vehicle 9930 re-routing from node 29841 due to congestion on edge 85958.
# [Time 21472.1 sec] Vehicle 9930 reached maximum re-route attempts at node 29841. Proceeding on current route.
# [Time 21473.0 sec] Vehicle 9796 reached destination 30751.
# [Time 21475.8 sec] Vehicle 9901 reached destination 70385.
# [Time 21478.2 sec] Vehicle 9900 re-routing from node 65966 due to congestion on edge 78807.
# [Time 21478.2 sec] Vehicle 9900 re-routing from node 65966 due to congestion on edge 78807.
# [Time 21478.2 sec] Vehicle 9900 re-routing from node 65966 due to congestion on edge 78807.
# [Time 21478.2 sec] Vehicle 9900 reached maximum re-route attempts at node 65966. Proceeding on current route.
# [Sim Time 21480.0 sec] Launched batch of 20 vehicles.
# [Time 21482.0 sec] Vehicle 7042 re-routing from node 33493 due to congestion on edge 33347_rev.
# [Time 21482.0 sec] Vehicle 7042 re-routing from node 33493 due to congestion on edge 33347_rev.
# [Time 21482.0 sec] Vehicle 7042 re-routing from node 33493 due to congestion on edge 33347_rev.
# [Time 21482.0 sec] Vehicle 7042 reached maximum re-route attempts at node 33493. Proceeding on current route.
# [Time 21487.7 sec] Vehicle 9916 re-routing from node 44992 due to congestion on edge 51864.
# [Time 21487.7 sec] Vehicle 9916 re-routing from node 44992 due to congestion on edge 51864.
# [Time 21487.7 sec] Vehicle 9916 re-routing from node 44992 due to congestion on edge 51864.
# [Time 21487.7 sec] Vehicle 9916 reached maximum re-route attempts at node 44992. Proceeding on current route.
# [Time 21499.7 sec] Vehicle 9759 reached destination 65905.
# [Time 21509.2 sec] Vehicle 9697 re-routing from node 33728 due to congestion on edge 33592.
# [Time 21513.0 sec] Vehicle 9749 reached destination 46173.
# [Time 21513.2 sec] Vehicle 9131 re-routing from node 67739 due to congestion on edge 78824.
# [Time 21513.2 sec] Vehicle 9131 re-routing from node 67739 due to congestion on edge 78824.
# [Time 21513.2 sec] Vehicle 9131 re-routing from node 67739 due to congestion on edge 78824.
# [Time 21513.2 sec] Vehicle 9131 reached maximum re-route attempts at node 67739. Proceeding on current route.
# [Time 21517.5 sec] Vehicle 9920 re-routing from node 68901 due to congestion on edge 88148.
# [Time 21517.5 sec] Vehicle 9920 re-routing from node 68901 due to congestion on edge 88148.
# [Time 21517.5 sec] Vehicle 9920 re-routing from node 68901 due to congestion on edge 88148.
# [Time 21517.5 sec] Vehicle 9920 reached maximum re-route attempts at node 68901. Proceeding on current route.
# [Time 21517.8 sec] Vehicle 9758 reached destination 30590.
# [Time 21521.5 sec] Vehicle 9782 reached destination 45898.
# [Time 21524.0 sec] Vehicle 9456 reached destination 32584.
# [Time 21527.8 sec] Vehicle 9699 re-routing from node 31404 due to congestion on edge 31221.
# [Time 21527.8 sec] Vehicle 9699 re-routing from node 31404 due to congestion on edge 31494.
# [Time 21527.8 sec] Vehicle 9699 re-routing from node 31404 due to congestion on edge 31494.
# [Time 21527.8 sec] Vehicle 9699 reached maximum re-route attempts at node 31404. Proceeding on current route.
# [Time 21530.2 sec] Vehicle 9955 re-routing from node 28929 due to congestion on edge 28795_rev.
# [Time 21530.2 sec] Vehicle 9955 re-routing from node 28929 due to congestion on edge 28795_rev.
# [Time 21530.2 sec] Vehicle 9955 re-routing from node 28929 due to congestion on edge 28795_rev.
# [Time 21530.2 sec] Vehicle 9955 reached maximum re-route attempts at node 28929. Proceeding on current route.
# [Time 21538.3 sec] Vehicle 9836 re-routing from node 33827 due to congestion on edge 33684_rev.
# [Time 21538.9 sec] Vehicle 9921 reached destination 43644.
# [Time 21539.1 sec] Vehicle 9935 re-routing from node 63150 due to congestion on edge 63753.
# [Time 21539.1 sec] Vehicle 9935 re-routing from node 63150 due to congestion on edge 63753.
# [Time 21539.1 sec] Vehicle 9935 re-routing from node 63150 due to congestion on edge 63753.
# [Time 21539.1 sec] Vehicle 9935 reached maximum re-route attempts at node 63150. Proceeding on current route.
# [Sim Time 21540.0 sec] Launched batch of 20 vehicles.
# [Time 21544.7 sec] Vehicle 9957 re-routing from node 31404 due to congestion on edge 31494.
# [Time 21544.7 sec] Vehicle 9957 re-routing from node 31404 due to congestion on edge 31221.
# [Time 21544.7 sec] Vehicle 9957 re-routing from node 31404 due to congestion on edge 31221.
# [Time 21544.7 sec] Vehicle 9957 reached maximum re-route attempts at node 31404. Proceeding on current route.
# [Time 21547.4 sec] Vehicle 9691 reached destination 28024.
# [Time 21550.2 sec] Vehicle 9969 re-routing from node 30737 due to congestion on edge 30560.
# [Time 21550.2 sec] Vehicle 9969 re-routing from node 30737 due to congestion on edge 30560.
# [Time 21550.2 sec] Vehicle 9969 re-routing from node 30737 due to congestion on edge 30560.
# [Time 21550.2 sec] Vehicle 9969 reached maximum re-route attempts at node 30737. Proceeding on current route.
# [Time 21550.4 sec] Vehicle 9885 re-routing from node 77491 due to congestion on edge 85959.
# [Time 21550.4 sec] Vehicle 9885 re-routing from node 77491 due to congestion on edge 85959.
# [Time 21550.4 sec] Vehicle 9885 re-routing from node 77491 due to congestion on edge 85959.
# [Time 21550.4 sec] Vehicle 9885 reached maximum re-route attempts at node 77491. Proceeding on current route.
# [Time 21552.6 sec] Vehicle 9934 re-routing from node 44183 due to congestion on edge 43892.
# [Time 21552.6 sec] Vehicle 9934 re-routing from node 44183 due to congestion on edge 43892.
# [Time 21552.6 sec] Vehicle 9934 re-routing from node 44183 due to congestion on edge 43892.
# [Time 21552.6 sec] Vehicle 9934 reached maximum re-route attempts at node 44183. Proceeding on current route.
# [Time 21553.2 sec] Vehicle 9737 reached destination 73688.
# [Time 21567.5 sec] Vehicle 9819 reached destination 79444.
# [Time 21570.5 sec] Vehicle 9946 re-routing from node 68759 due to congestion on edge 70998_rev.
# [Time 21570.8 sec] Vehicle 9922 re-routing from node 33480 due to congestion on edge 46710.
# [Time 21570.8 sec] Vehicle 9922 re-routing from node 33480 due to congestion on edge 46710.
# [Time 21570.8 sec] Vehicle 9922 re-routing from node 33480 due to congestion on edge 46710.
# [Time 21570.8 sec] Vehicle 9922 reached maximum re-route attempts at node 33480. Proceeding on current route.
# [Time 21571.1 sec] Vehicle 9823 reached destination 79097.
# [Time 21572.9 sec] Vehicle 9844 re-routing from node 42098 due to congestion on edge 77061.
# [Time 21572.9 sec] Vehicle 9844 re-routing from node 42098 due to congestion on edge 77061.
# [Time 21572.9 sec] Vehicle 9844 re-routing from node 42098 due to congestion on edge 77061.
# [Time 21572.9 sec] Vehicle 9844 reached maximum re-route attempts at node 42098. Proceeding on current route.
# [Time 21576.5 sec] Vehicle 9954 re-routing from node 48808 due to congestion on edge 49245.
# [Time 21576.5 sec] Vehicle 9954 re-routing from node 48808 due to congestion on edge 49245.
# [Time 21576.5 sec] Vehicle 9954 re-routing from node 48808 due to congestion on edge 49245.
# [Time 21576.5 sec] Vehicle 9954 reached maximum re-route attempts at node 48808. Proceeding on current route.
# [Time 21579.3 sec] Vehicle 9803 re-routing from node 46844 due to congestion on edge 46877_rev.
# [Time 21579.3 sec] Vehicle 9803 re-routing from node 46844 due to congestion on edge 46877_rev.
# [Time 21579.3 sec] Vehicle 9803 re-routing from node 46844 due to congestion on edge 46877_rev.
# [Time 21579.3 sec] Vehicle 9803 reached maximum re-route attempts at node 46844. Proceeding on current route.
# [Time 21580.4 sec] Vehicle 9855 re-routing from node 48662 due to congestion on edge 49073.
# [Time 21582.9 sec] Vehicle 9798 reached destination 71347.
# [Time 21586.1 sec] Vehicle 9852 re-routing from node 31404 due to congestion on edge 31494.
# [Time 21586.1 sec] Vehicle 9852 re-routing from node 31404 due to congestion on edge 31494.
# [Time 21586.1 sec] Vehicle 9852 re-routing from node 31404 due to congestion on edge 31494.
# [Time 21586.1 sec] Vehicle 9852 reached maximum re-route attempts at node 31404. Proceeding on current route.
# [Time 21586.3 sec] Vehicle 9697 reached destination 42534.
# [Time 21590.0 sec] Vehicle 9846 reached destination 33603.
# [Time 21592.5 sec] Vehicle 9973 re-routing from node 32889 due to congestion on edge 80678.
# [Time 21592.5 sec] Vehicle 9973 re-routing from node 32889 due to congestion on edge 80678.
# [Time 21592.5 sec] Vehicle 9973 re-routing from node 32889 due to congestion on edge 80678.
# [Time 21592.5 sec] Vehicle 9973 reached maximum re-route attempts at node 32889. Proceeding on current route.
# Simulation complete.

# %%
# Save occupancy snapshots to a df and save it to a csv file
occupancy_snapshots_df = pd.DataFrame(occupancy_snapshots)
occupancy_snapshots_df.to_csv("occupancy_snapshots.csv", index=False)

# %%
if residential_nodes and office_nodes:
    query_source = random.choice(residential_nodes)
    query_destination = random.choice(office_nodes)
    print(f"\nQuerying routes from residential node {query_source} to office node {query_destination} at hourly intervals:")
    route_queries = query_routes_at_intervals(query_source, query_destination, interval=600, total_duration=SIM_DURATION)
    for query_time, route, travel_time in route_queries:
        if route is not None:
            total_length = route_length(route) / 1000.0
            print(f"  At {query_time/3600:.1f} hr: Route length = {total_length:.2f} km; Estimated travel time = {travel_time/60:.2f} min; edges: {[edge['edge_id'] for edge in route]}")
        else:
            print(f"  At {query_time/3600:.1f} hr: No route found.")
else:
    print("Not enough nodes for realistic route queries.")
# Out:
# Querying routes from residential node 31130 to office node 33783 at hourly intervals:
# No occupancy snapshots available.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[165], line 5
#       3 query_destination = random.choice(office_nodes)
#       4 print(f"\nQuerying routes from residential node {query_source} to office node {query_destination} at hourly intervals:")
# ----> 5 route_queries = query_routes_at_intervals(query_source, query_destination, interval=600, total_duration=SIM_DURATION)
#       6 for query_time, route, travel_time in route_queries:
#       7     if route is not None:
#
# Cell In[128], line 23, in query_routes_at_intervals(source, destination, interval, total_duration)
#      21 t = 0
#      22 while t <= total_duration:
# ---> 23     route, travel_time = query_route_at_time(t, source, destination)
#      24     queries.append((t, route, travel_time))
#      25     t += interval
#
# TypeError: cannot unpack non-iterable NoneType object

# %% [markdown]
#  SECTION 7: VISUALIZATION (ANIMATION OF OCCUPANCY)
#
#  We animate the network by coloring each edge according to its occupancy fraction.

# %%
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
import numpy as np
from PIL import Image
import io

def animate_network(edges_gdf, occupancy_snapshots, interval=200):

    # Build the network segments, edge IDs, and capacities
    segments = []
    edge_ids = []
    capacities = []
    for _, row in edges_gdf.iterrows():
        if row.geometry.geom_type == 'LineString':
            segments.append(list(row.geometry.coords))
            edge_ids.append(row["id"])
            capacities.append(row["capacity"])
        elif row.geometry.geom_type == 'MultiLineString':
            for line in row.geometry:
                segments.append(list(line.coords))
                edge_ids.append(row["id"])
                capacities.append(row["capacity"])
        # Skip other geometry types

    fig, ax = plt.subplots(figsize=(10, 8))
    ax.set_aspect('equal')
    ax.set_title("Dynamic Network Congestion")
    ax.set_xlabel("X")
    ax.set_ylabel("Y")

    # Add background network with thin gray lines
    background_lc = LineCollection(segments, colors='lightgray', linewidths=1.2, zorder=1)
    ax.add_collection(background_lc)

    norm = plt.Normalize(0, 1)
    lc = LineCollection(segments, cmap='Reds', norm=norm, zorder=2)
    lc.set_array(np.zeros(len(segments)))
    lc.set_linewidth(1)
    ax.add_collection(lc)
    
    all_coords = np.concatenate(segments)
    ax.set_xlim(np.min(all_coords[:, 0]) - 0.01, np.max(all_coords[:, 0]) + 0.01)
    ax.set_ylim(np.min(all_coords[:, 1]) - 0.01, np.max(all_coords[:, 1]) + 0.01)
    cbar = plt.colorbar(lc, ax=ax)
    cbar.set_label("Occupancy Fraction (occupancy / capacity)")
    time_text = ax.text(0.02, 0.95, "", transform=ax.transAxes, fontsize=12, color="blue")
    capacity_dict = {eid: cap for eid, cap in zip(edge_ids, capacities)}

    # --- Filter snapshots based on the desired time interval ---
    filtered_snapshots = []
    last_frame_time = -np.inf
    for sim_time, occ_dict in occupancy_snapshots:
        if sim_time - last_frame_time >= interval:
            filtered_snapshots.append((sim_time, occ_dict))
            last_frame_time = sim_time

    frames = []
    for sim_time, occ_dict in filtered_snapshots:
        # Compute occupancy fractions for each edge
        occ_fractions = []
        for eid in edge_ids:
            occ = occ_dict.get(eid, 0)
            cap = capacity_dict.get(eid, 1)
            fraction = min(occ / cap, 1.0)
            occ_fractions.append(fraction)
        lc.set_array(np.array(occ_fractions))
        time_text.set_text(f"Sim Time: {sim_time:.1f} sec")
        
        # Render the figure to a buffer and create an image
        fig.canvas.draw()
        buf = io.BytesIO()
        fig.savefig(buf, format='png', dpi=300, bbox_inches='tight', pad_inches=0.1)
        buf.seek(0)
        img = Image.open(buf)
        frames.append(img.copy())
        buf.close()
    
    plt.close(fig)
    return frames

# Create the animation frames using the filtered snapshots
frames = animate_network(edges_gdf, occupancy_snapshots, interval=200)

# Save the frames as a GIF with the specified display duration for each frame
frames[0].save("congestion.gif", save_all=True, append_images=frames[1:], duration=200, loop=0)

print("Animation saved as congestion.gif")
# Out:
# Animation saved as congestion.gif
